# %%
# !pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# !pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# !pip install -q torch-geometric
# !pip install ogb
# Out:
#      |████████████████████████████████| 2.6MB 3.8MB/s
#      |████████████████████████████████| 1.5MB 8.5MB/s
#      |████████████████████████████████| 194kB 8.7MB/s
#      |████████████████████████████████| 235kB 43.4MB/s
#      |████████████████████████████████| 2.2MB 47.7MB/s
#      |████████████████████████████████| 51kB 8.5MB/s
#   Building wheel for torch-geometric (setup.py) ... done
# Collecting ogb
#   Downloading https://files.pythonhosted.org/packages/34/47/16573587124ee85c8255cebd30c55981fa78c815eaff966ff111fb11c32c/ogb-1.3.0-py3-none-any.whl (67kB)
#      |████████████████████████████████| 71kB 5.0MB/s
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from ogb) (1.15.0)
# Requirement already satisfied: torch>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from ogb) (1.8.0+cu101)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from ogb) (0.22.2.post1)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from ogb) (1.1.5)
# Collecting outdated>=0.2.0
#   Downloading https://files.pythonhosted.org/packages/86/70/2f166266438a30e94140f00c99c0eac1c45807981052a1d4c123660e1323/outdated-0.2.0.tar.gz
# Requirement already satisfied: tqdm>=4.29.0 in /usr/local/lib/python3.7/dist-packages (from ogb) (4.41.1)
# Requirement already satisfied: urllib3>=1.24.0 in /usr/local/lib/python3.7/dist-packages (from ogb) (1.24.3)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from ogb) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.2.0->ogb) (3.7.4.3)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->ogb) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->ogb) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->ogb) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->ogb) (2018.9)
# Collecting littleutils
#   Downloading https://files.pythonhosted.org/packages/4e/b1/bb4e06f010947d67349f863b6a2ad71577f85590180a935f60543f622652/littleutils-0.2.2.tar.gz
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from outdated>=0.2.0->ogb) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->outdated>=0.2.0->ogb) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->outdated>=0.2.0->ogb) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->outdated>=0.2.0->ogb) (3.0.4)
# Building wheels for collected packages: outdated, littleutils
#   Building wheel for outdated (setup.py) ... done
#   Created wheel for outdated: filename=outdated-0.2.0-cp37-none-any.whl size=4962 sha256=d3073facc7a37258673d77f9890b0aecda4ac25110f76ed700702eb339da1b63
#   Stored in directory: /root/.cache/pip/wheels/fd/7c/ef/814f514d31197310872b5abf353feb8fef9d67ee658e1e7e39
#   Building wheel for littleutils (setup.py) ... done
#   Created wheel for littleutils: filename=littleutils-0.2.2-cp37-none-any.whl size=7051 sha256=32cfeb46f697fa545ad25b0a15e0ec8bd065acd32f2c2eba4f9b630c4c6eb002
#   Stored in directory: /root/.cache/pip/wheels/53/16/9f/ac67d15c40243754fd73f620e1b9b6dedc20492ecc19a2bae1
# Successfully built outdated littleutils
# Installing collected packages: littleutils, outdated, ogb
# Successfully installed littleutils-0.2.2 ogb-1.3.0 outdated-0.2.0

# %%
import torch
import copy
import numpy as np
import networkx as nx
import random
import pandas as pd

import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import DataLoader
from torch_geometric.utils import negative_sampling, to_networkx
from torch_geometric.nn import GCNConv, SAGEConv, TAGConv, JumpingKnowledge

import torch_sparse

# %%
# !nvidia-smi
# Out:
# Sun Mar 21 20:50:36 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.56       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8    10W /  70W |      3MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Load Dataset

# %%
from ogb.linkproppred import PygLinkPropPredDataset, Evaluator

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Device: {}'.format(device))

dataset = PygLinkPropPredDataset(name='ogbl-ddi')
print('Task type: {}'.format(dataset.task_type))
graph = dataset[0]
# print(graph)

# Train-Val-Test split
split_idx = dataset.get_edge_split()

evaluator = Evaluator(name = 'ogbl-ddi')
print(evaluator.expected_input_format) 
print(evaluator.expected_output_format) 

# 2 x (Number of edges*2)
edge_index = graph.edge_index
print('edge_index:')
print(edge_index)
print(edge_index.shape)

# Number of nodes x Number of nodes
adj_t = torch_sparse.SparseTensor.from_edge_index(edge_index)
print('adj_t:')
print(adj_t)
# Out:
#   0%|          | 0/46 [00:00<?, ?it/s]
# Device: cuda
# Downloading http://snap.stanford.edu/ogb/data/linkproppred/ddi.zip
# Downloaded 0.04 GB: 100%|██████████| 46/46 [00:15<00:00,  3.02it/s]
# Extracting dataset/ddi.zip
#   0%|          | 0/1 [00:00<?, ?it/s]
# Processing...
# Loading necessary files...
# This might take a while.
# Processing graphs...
# 100%|██████████| 1/1 [00:00<00:00, 35.84it/s]
# 100%|██████████| 1/1 [00:00<00:00, 632.05it/s]
# Converting graphs into PyG objects...
# Saving...
# Done!
# Task type: link prediction
# ==== Expected input format of Evaluator for ogbl-ddi
# {'y_pred_pos': y_pred_pos, 'y_pred_neg': y_pred_neg}
# - y_pred_pos: numpy ndarray or torch tensor of shape (num_edge, ). Torch tensor on GPU is recommended for efficiency.
# - y_pred_neg: numpy ndarray or torch tensor of shape (num_edge, ). Torch tensor on GPU is recommended for efficiency.
# y_pred_pos is the predicted scores for positive edges.
# y_pred_neg is the predicted scores for negative edges.
# Note: As the evaluation metric is ranking-based, the predicted scores need to be different for different edges.
# ==== Expected output format of Evaluator for ogbl-ddi
# {hits@20': hits@20}
# - hits@20 (float): Hits@20 score
#
# edge_index:
# tensor([[4039, 2424, 4039,  ...,  338,  835, 3554],
#         [2424, 4039,  225,  ...,  708, 3554,  835]])
# torch.Size([2, 2135822])
# adj_t:
# SparseTensor(row=tensor([   0,    0,    0,  ..., 4266, 4266, 4266]),
#              col=tensor([   4,    6,    7,  ..., 3953, 3972, 4014]),
#              size=(4267, 4267), nnz=2135822, density=11.73%)

# %%
print('Train edges:', split_idx['train']['edge'].shape)
# print('Train negative edges:', split_idx['train']['edge_neg'].shape)

print('Val edges:', split_idx['valid']['edge'].shape)
print('Val negative edges:', split_idx['valid']['edge_neg'].shape)

print('Test edges:', split_idx['test']['edge'].shape)
print('Test negative edges:', split_idx['test']['edge_neg'].shape)
# Out:
# Train edges: torch.Size([1067911, 2])
# Val edges: torch.Size([133489, 2])
# Val negative edges: torch.Size([101882, 2])
# Test edges: torch.Size([133489, 2])
# Test negative edges: torch.Size([95599, 2])

# %% [markdown]
# # Preprocess Data for DE-GNN

# %%
nx_graph = to_networkx(graph, to_undirected=True)
nx_degree = nx.degree(nx_graph)
nx_pagerank = nx.pagerank(nx_graph)
# slow
nx_clustering = nx.clustering(nx_graph)
nx_centrality = nx.closeness_centrality(nx_graph)

# %%
# Shortest Path Distance 
def get_spd_matrix(G, S, max_spd=5):
    spd_matrix = np.zeros((G.number_of_nodes(), max_spd + 1), dtype=np.int32)
    for i, node_S in enumerate(S):
        for node, length in nx.shortest_path_length(G, source=node_S).items():
            spd_matrix[node, min(length, max_spd)] += 1
    return spd_matrix /(len(S))

# Random Walk Landing Probablity (S = all nodes)
def get_lp_matrix(A, max_steps=5):
    W = A / A.sum(1, keepdims=True)
    W_list = [np.identity(A.shape[0])]
    for i in range(max_steps):
        W_list.append(np.matmul(W_list[-1], W))

    W_stack = np.stack(W_list, axis=2)  
    return W_stack.mean(axis=0)

# %%
# S = 200 random nodes, slow
np.random.seed(0)
node_subset = np.random.choice(nx_graph.number_of_nodes(), size=200, replace=False)
spd_feature = get_spd_matrix(G=nx_graph, S=node_subset, max_spd=5)
print(spd_feature)
print(spd_feature.shape)

# S = all nodes
lp_feature = get_lp_matrix(adj_t.to_dense(), max_steps=5)
print(lp_feature)
print(lp_feature.shape)
# Out:
# [[0.    0.12  0.74  0.135 0.005 0.   ]
#  [0.    0.1   0.565 0.33  0.005 0.   ]
#  [0.    0.    0.225 0.725 0.045 0.005]
#  ...
#  [0.    0.005 0.04  0.74  0.21  0.005]
#  [0.    0.01  0.705 0.28  0.005 0.   ]
#  [0.    0.    0.575 0.42  0.005 0.   ]]
# (4267, 6)
# [[2.34356691e-04 2.93526852e-04 2.23200240e-04 2.45474974e-04
#   2.20286597e-04 2.23163665e-04]
#  [2.34356691e-04 1.80790480e-04 2.31190380e-04 1.76067754e-04
#   1.92013031e-04 1.67547330e-04]
#  [2.34356691e-04 1.87849777e-06 8.47383599e-05 2.61183075e-06
#   3.26818208e-05 2.56206488e-06]
#  ...
#  [2.34356691e-04 3.70326652e-05 1.97831345e-05 1.53761192e-05
#   1.03435513e-05 9.72830004e-06]
#  [2.34356691e-04 5.87933213e-05 5.66102474e-05 2.75958480e-05
#   2.91710197e-05 2.42242912e-05]
#  [2.34356691e-04 4.25467285e-06 3.23737135e-05 8.08685402e-06
#   1.12771452e-05 8.52324894e-06]]
# (4267, 6)

# %%
# Convert to tensor
tensor_degree = torch.Tensor([t[1] for t in nx_degree]).unsqueeze(1)
tensor_pagerank = torch.Tensor([t[1] for t in nx_pagerank.items()]).unsqueeze(1)
tensor_clustering = torch.Tensor([t[1] for t in nx_clustering.items()]).unsqueeze(1)
tensor_centrality = torch.Tensor([t[1] for t in nx_centrality.items()]).unsqueeze(1)

tensor_spd = torch.Tensor(spd_feature)
tensor_lp = torch.Tensor(lp_feature)

# Concat
feature_tensor_list = [tensor_degree, tensor_pagerank, tensor_clustering,
                       tensor_centrality, tensor_spd, tensor_lp]
x_feature = torch.cat(feature_tensor_list, dim=1)
print(x_feature.shape)
# Out:
# torch.Size([4267, 16])

# %%
# x_feature_numpy = x_feature.numpy()
# x_df = pd.DataFrame(x_feature_numpy)
# x_df.to_csv('x_feature.csv', index=False)

# %%
# Use this chunk to skip preprecessing

# x_df = pd.read_csv('x_feature.csv')
# x_feature_numpy = x_df.to_numpy()
# x_feature = torch.Tensor(x_feature_numpy)
# print(x_feature.shape)

# %%
# Normalize to 0-1
x_max = torch.max(x_feature, dim=0, keepdim=True)[0]
x_min = torch.min(x_feature, dim=0, keepdim=True)[0]
x_feature = (x_feature - x_min)/(x_max - x_min + 1e-6)

# %%
edge_index = edge_index.to(device)
adj_t = adj_t.to(device)
x_feature = x_feature.to(device)

# %%
def train(model, optimizer, evaluator, graph, x_feature, edge_index, adj_t, split_idx,
          batch_size=1024*64, num_epochs=200, save_model=False):
    best_val_score = 0
    best_epoch = 0
    best_test_score = 0
    best_model = model

    all_pos_edges = split_idx['train']['edge'].transpose(0,1).to(device)

    for epoch in range(1, num_epochs+1):
        sum_loss = 0
        count = 0 
        for batch in DataLoader(list(range(all_pos_edges.shape[1])), batch_size=batch_size, shuffle=True):
            model.train()
            batch_pos_edges = all_pos_edges[:, batch]
            batch_neg_edges = negative_sampling(edge_index=edge_index, 
                                            num_nodes=graph.num_nodes,
                                            num_neg_samples=batch_pos_edges.shape[1], 
                                            method='dense').to(device)
            edge_label_index = torch.cat([batch_pos_edges, batch_neg_edges], dim=1).to(device)
          
            pos_label = torch.ones(batch_pos_edges.shape[1], )
            neg_label = torch.zeros(batch_neg_edges.shape[1], )
            edge_label = torch.cat([pos_label, neg_label], dim=0).to(device)

            optimizer.zero_grad()  
            pred = model(x_feature, adj_t, edge_label_index)
            loss = model.loss(pred, edge_label.type_as(pred))
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        
            optimizer.step()

            sum_loss += loss.item() * edge_label.shape[0]
            count += edge_label.shape[0]

        val_score, test_score = evaluate(model, x_feature, adj_t, split_idx, evaluator)
        if best_val_score < val_score:
            best_val_score = val_score
            best_epoch = epoch
            best_test_score = test_score
            if save_model:
                best_model = copy.deepcopy(model)

        log = 'Epoch: {:03d}, Loss: {:.4f}, Val Hits: {:.2f}%, Test Hits: {:.2f}%'
        print(log.format(epoch, sum_loss/count, 100*val_score, 100*test_score))

    print('Final model:')
    log = 'Epoch: {:03d}, Val Hits: {:.2f}%, Test Hits: {:.2f}%'
    print(log.format(best_epoch, 100*best_val_score, 100*best_test_score))
    return best_model, best_val_score, best_test_score

@torch.no_grad()
def evaluate(model, x_feature, adj_t, split_idx, evaluator):
    model.eval()

    pos_edge_label_index = split_idx['valid']['edge'].transpose(0,1)
    neg_edge_label_index = split_idx['valid']['edge_neg'].transpose(0,1)
    
    y_pred_pos = model(x_feature, adj_t, pos_edge_label_index)
    y_pred_neg = model(x_feature, adj_t, neg_edge_label_index)
    
    score_val = evaluator.eval({'y_pred_pos': y_pred_pos, 'y_pred_neg': y_pred_neg})['hits@20']

    pos_edge_label_index = split_idx['test']['edge'].transpose(0,1)
    neg_edge_label_index = split_idx['test']['edge_neg'].transpose(0,1)
    
    y_pred_pos = model(x_feature, adj_t, pos_edge_label_index)
    y_pred_neg = model(x_feature, adj_t, neg_edge_label_index)
    
    score_test = evaluator.eval({'y_pred_pos': y_pred_pos, 'y_pred_neg': y_pred_neg})['hits@20']

    return (score_val, score_test)

# %% [markdown]
# # DEA-GCN-JK

# %% [markdown]
# ## Model

# %%
class DEA_GNN_JK(torch.nn.Module):
    def __init__(self, num_nodes, embed_dim, 
                 gnn_in_dim, gnn_hidden_dim, gnn_out_dim, gnn_num_layers, 
                 mlp_in_dim, mlp_hidden_dim, mlp_out_dim=1, mlp_num_layers=2, 
                 dropout=0.5, gnn_batchnorm=False, mlp_batchnorm=False, K=2, jk_mode='max'):
        super(DEA_GNN_JK, self).__init__()
        
        assert jk_mode in ['max','sum','mean','lstm','cat']
        # Embedding
        self.emb = torch.nn.Embedding(num_nodes, embedding_dim=embed_dim)

        # GNN 
        convs_list = [TAGConv(gnn_in_dim, gnn_hidden_dim, K)]
        for i in range(gnn_num_layers-2):
            convs_list.append(TAGConv(gnn_hidden_dim, gnn_hidden_dim, K))
        convs_list.append(TAGConv(gnn_hidden_dim, gnn_out_dim, K))
        self.convs = torch.nn.ModuleList(convs_list)

        # MLP
        lins_list = [torch.nn.Linear(mlp_in_dim, mlp_hidden_dim)]
        for i in range(mlp_num_layers-2):
            lins_list.append(torch.nn.Linear(mlp_hidden_dim, mlp_hidden_dim))
        lins_list.append(torch.nn.Linear(mlp_hidden_dim, mlp_out_dim))
        self.lins = torch.nn.ModuleList(lins_list)

        # Batchnorm
        self.gnn_batchnorm = gnn_batchnorm
        self.mlp_batchnorm = mlp_batchnorm
        if self.gnn_batchnorm:
            self.gnn_bns = torch.nn.ModuleList([torch.nn.BatchNorm1d(gnn_hidden_dim) for i in range(gnn_num_layers)])
        
        if self.mlp_batchnorm:
            self.mlp_bns = torch.nn.ModuleList([torch.nn.BatchNorm1d(mlp_hidden_dim) for i in range(mlp_num_layers-1)])

        self.jk_mode = jk_mode
        if self.jk_mode in ['max', 'lstm', 'cat']:
            self.jk = JumpingKnowledge(mode=self.jk_mode, channels=gnn_hidden_dim, num_layers=gnn_num_layers)

        self.dropout = dropout
        self.loss_fn = torch.nn.BCEWithLogitsLoss()
        self.reset_parameters()

    def reset_parameters(self):
        torch.nn.init.xavier_uniform_(self.emb.weight)  
        for conv in self.convs:
            conv.reset_parameters()
        for lin in self.lins:
            lin.reset_parameters()
        if self.gnn_batchnorm:
            for bn in self.gnn_bns:
                bn.reset_parameters()
        if self.mlp_batchnorm:
            for bn in self.mlp_bns:
                bn.reset_parameters()
        if self.jk_mode in ['max', 'lstm', 'cat']:
            self.jk.reset_parameters()

    def forward(self, x_feature, adj_t, edge_label_index):
        
        if x_feature is not None:
            out = torch.cat([self.emb.weight, x_feature], dim=1)
        else:
            out = self.emb.weight

        out_list = []
        for i in range(len(self.convs)):
            out = self.convs[i](out, adj_t)
            if self.gnn_batchnorm:
                out = self.gnn_bns[i](out)
            out = F.relu(out)
            out = F.dropout(out, p=self.dropout, training=self.training)
            out_list += [out]

        if self.jk_mode in ['max', 'lstm', 'cat']:
            out = self.jk(out_list)
        elif self.jk_mode == 'mean':
            out_stack = torch.stack(out_list, dim=0)
            out = torch.mean(out_stack, dim=0)
        elif self.jk_mode == 'sum':
            out_stack = torch.stack(out_list, dim=0)
            out = torch.sum(out_stack, dim=0)

        gnn_embed = out[edge_label_index,:]
        embed_product = gnn_embed[0, :, :] * gnn_embed[1, :, :]
        out = embed_product

        for i in range(len(self.lins)-1):
            out = self.lins[i](out)
            if self.mlp_batchnorm:
                out = self.mlp_bns[i](out)
            out = F.relu(out)
            out = F.dropout(out, p=self.dropout, training=self.training)
        out = self.lins[-1](out).squeeze(1)

        return out
    
    def loss(self, y_pred, y_true):
        return self.loss_fn(y_pred, y_true)

# %% [markdown]
# ## Train

# %%
# mlp_out_dim = 1
# gnn_num_layers >= 2
# mlp_num_layers >= 2
# jk_mode = cat, max, lstm，mean, sum 

USE_DE = True
gnn_in_dim = 0

if USE_DE: 
    gnn_in_dim = 256 + x_feature.shape[1]
else:
    gnn_in_dim = 256 

model = DEA_GNN_JK(num_nodes=graph.num_nodes, embed_dim=256, 
               gnn_in_dim=gnn_in_dim, gnn_hidden_dim=256, gnn_out_dim=256, gnn_num_layers=3, 
               mlp_in_dim=256, mlp_hidden_dim=256, mlp_out_dim=1, mlp_num_layers=2, 
               dropout=0.5, gnn_batchnorm=True, mlp_batchnorm=True, K=2, jk_mode='max').to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.005)
print(model)
print('Number of parameters:', sum(p.numel() for p in model.parameters()))
# Out:
# DEA_GNN_JK(
#   (emb): Embedding(4267, 256)
#   (convs): ModuleList(
#     (0): TAGConv(272, 256, K=2)
#     (1): TAGConv(256, 256, K=2)
#     (2): TAGConv(256, 256, K=2)
#   )
#   (lins): ModuleList(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#     (1): Linear(in_features=256, out_features=1, bias=True)
#   )
#   (gnn_bns): ModuleList(
#     (0): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (mlp_bns): ModuleList(
#     (0): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (jk): JumpingKnowledge(max)
#   (loss_fn): BCEWithLogitsLoss()
# )
# Number of parameters: 1763329

# %%
# Multiple runs
RUNS = 10
best_val_scores = np.zeros((RUNS,))
best_test_scores = np.zeros((RUNS,))

for i in range(RUNS):
    random.seed(i+1)
    torch.manual_seed(i+1)
    model.reset_parameters()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.005)

    if USE_DE:
        result = train(model, optimizer, evaluator, graph, x_feature, edge_index, adj_t, split_idx,
                       batch_size=1024*64, num_epochs=400, save_model=False)
    else:
        result = train(model, optimizer, evaluator, graph, None, edge_index, adj_t, split_idx,
                       batch_size=1024*64, num_epochs=400, save_model=False) 
    
    best_val_scores[i] = result[1]
    best_test_scores[i] = result[2]

    print('Run', i+1, 'done.')
    
log = 'Mean Val Hits: {:.4f}, SD Val Hits: {:.4f}'
print(log.format(np.mean(best_val_scores), np.std(best_val_scores, ddof=1)))
log = 'Mean Test Hits: {:.4f}, SD Test Hits: {:.4f}'
print(log.format(np.mean(best_test_scores), np.std(best_test_scores, ddof=1)))
# Out:
# Epoch: 001, Loss: 0.4247, Val Hits: 2.11%, Test Hits: 1.16%
# Epoch: 002, Loss: 0.3419, Val Hits: 4.48%, Test Hits: 1.95%
# Epoch: 003, Loss: 0.2976, Val Hits: 12.52%, Test Hits: 13.36%
# Epoch: 004, Loss: 0.2611, Val Hits: 8.69%, Test Hits: 5.32%
# Epoch: 005, Loss: 0.2355, Val Hits: 5.96%, Test Hits: 2.88%
# Epoch: 006, Loss: 0.2150, Val Hits: 7.92%, Test Hits: 3.47%
# Epoch: 007, Loss: 0.1982, Val Hits: 9.39%, Test Hits: 4.07%
# Epoch: 008, Loss: 0.1862, Val Hits: 12.23%, Test Hits: 6.10%
# Epoch: 009, Loss: 0.1742, Val Hits: 13.21%, Test Hits: 6.35%
# Epoch: 010, Loss: 0.1659, Val Hits: 14.43%, Test Hits: 7.62%
# Epoch: 011, Loss: 0.1590, Val Hits: 14.68%, Test Hits: 10.69%
# Epoch: 012, Loss: 0.1527, Val Hits: 18.33%, Test Hits: 14.27%
# Epoch: 013, Loss: 0.1477, Val Hits: 19.44%, Test Hits: 18.43%
# Epoch: 014, Loss: 0.1434, Val Hits: 19.16%, Test Hits: 12.18%
# Epoch: 015, Loss: 0.1387, Val Hits: 19.38%, Test Hits: 20.96%
# Epoch: 016, Loss: 0.1359, Val Hits: 22.76%, Test Hits: 22.73%
# Epoch: 017, Loss: 0.1323, Val Hits: 27.28%, Test Hits: 26.93%
# Epoch: 018, Loss: 0.1303, Val Hits: 26.10%, Test Hits: 25.92%
# Epoch: 019, Loss: 0.1268, Val Hits: 26.96%, Test Hits: 26.08%
# Epoch: 020, Loss: 0.1256, Val Hits: 27.07%, Test Hits: 26.52%
# Epoch: 021, Loss: 0.1232, Val Hits: 25.85%, Test Hits: 25.18%
# Epoch: 022, Loss: 0.1213, Val Hits: 31.91%, Test Hits: 30.74%
# Epoch: 023, Loss: 0.1196, Val Hits: 31.85%, Test Hits: 30.01%
# Epoch: 024, Loss: 0.1177, Val Hits: 31.67%, Test Hits: 30.62%
# Epoch: 025, Loss: 0.1173, Val Hits: 34.64%, Test Hits: 29.76%
# Epoch: 026, Loss: 0.1155, Val Hits: 38.52%, Test Hits: 38.02%
# Epoch: 027, Loss: 0.1148, Val Hits: 38.98%, Test Hits: 37.97%
# Epoch: 028, Loss: 0.1132, Val Hits: 39.17%, Test Hits: 38.14%
# Epoch: 029, Loss: 0.1121, Val Hits: 38.40%, Test Hits: 41.55%
# Epoch: 030, Loss: 0.1113, Val Hits: 38.81%, Test Hits: 38.94%
# Epoch: 031, Loss: 0.1108, Val Hits: 40.90%, Test Hits: 36.98%
# Epoch: 032, Loss: 0.1094, Val Hits: 48.47%, Test Hits: 39.70%
# Epoch: 033, Loss: 0.1085, Val Hits: 41.74%, Test Hits: 36.11%
# Epoch: 034, Loss: 0.1083, Val Hits: 42.05%, Test Hits: 39.01%
# Epoch: 035, Loss: 0.1075, Val Hits: 43.23%, Test Hits: 39.53%
# Epoch: 036, Loss: 0.1071, Val Hits: 37.28%, Test Hits: 38.52%
# Epoch: 037, Loss: 0.1068, Val Hits: 43.99%, Test Hits: 48.59%
# Epoch: 038, Loss: 0.1062, Val Hits: 43.41%, Test Hits: 37.88%
# Epoch: 039, Loss: 0.1047, Val Hits: 41.10%, Test Hits: 38.04%
# Epoch: 040, Loss: 0.1052, Val Hits: 37.06%, Test Hits: 39.72%
# Epoch: 041, Loss: 0.1039, Val Hits: 46.99%, Test Hits: 43.92%
# Epoch: 042, Loss: 0.1038, Val Hits: 41.62%, Test Hits: 46.72%
# Epoch: 043, Loss: 0.1033, Val Hits: 45.96%, Test Hits: 45.66%
# Epoch: 044, Loss: 0.1026, Val Hits: 45.33%, Test Hits: 46.37%
# Epoch: 045, Loss: 0.1021, Val Hits: 48.61%, Test Hits: 45.67%
# Epoch: 046, Loss: 0.1018, Val Hits: 46.93%, Test Hits: 46.16%
# Epoch: 047, Loss: 0.1013, Val Hits: 41.86%, Test Hits: 41.18%
# Epoch: 048, Loss: 0.1015, Val Hits: 47.69%, Test Hits: 48.99%
# Epoch: 049, Loss: 0.1012, Val Hits: 51.07%, Test Hits: 48.82%
# Epoch: 050, Loss: 0.1001, Val Hits: 48.40%, Test Hits: 48.99%
# Epoch: 051, Loss: 0.1003, Val Hits: 50.59%, Test Hits: 52.89%
# Epoch: 052, Loss: 0.0999, Val Hits: 45.36%, Test Hits: 50.20%
# Epoch: 053, Loss: 0.0996, Val Hits: 47.79%, Test Hits: 50.67%
# Epoch: 054, Loss: 0.0994, Val Hits: 51.74%, Test Hits: 53.04%
# Epoch: 055, Loss: 0.0989, Val Hits: 50.60%, Test Hits: 51.18%
# Epoch: 056, Loss: 0.0992, Val Hits: 48.76%, Test Hits: 51.82%
# Epoch: 057, Loss: 0.0981, Val Hits: 47.51%, Test Hits: 48.43%
# Epoch: 058, Loss: 0.0980, Val Hits: 48.74%, Test Hits: 52.31%
# Epoch: 059, Loss: 0.0979, Val Hits: 47.32%, Test Hits: 53.36%
# Epoch: 060, Loss: 0.0981, Val Hits: 50.24%, Test Hits: 56.29%
# Epoch: 061, Loss: 0.0973, Val Hits: 52.30%, Test Hits: 52.72%
# Epoch: 062, Loss: 0.0971, Val Hits: 51.25%, Test Hits: 54.59%
# Epoch: 063, Loss: 0.0973, Val Hits: 53.88%, Test Hits: 54.43%
# Epoch: 064, Loss: 0.0967, Val Hits: 48.94%, Test Hits: 56.75%
# Epoch: 065, Loss: 0.0971, Val Hits: 49.32%, Test Hits: 54.74%
# Epoch: 066, Loss: 0.0959, Val Hits: 50.80%, Test Hits: 55.29%
# Epoch: 067, Loss: 0.0966, Val Hits: 50.29%, Test Hits: 54.03%
# Epoch: 068, Loss: 0.0960, Val Hits: 50.17%, Test Hits: 50.65%
# Epoch: 069, Loss: 0.0960, Val Hits: 52.27%, Test Hits: 57.42%
# Epoch: 070, Loss: 0.0952, Val Hits: 49.29%, Test Hits: 57.94%
# Epoch: 071, Loss: 0.0956, Val Hits: 52.59%, Test Hits: 60.46%
# Epoch: 072, Loss: 0.0958, Val Hits: 48.22%, Test Hits: 58.13%
# Epoch: 073, Loss: 0.0948, Val Hits: 51.43%, Test Hits: 56.21%
# Epoch: 074, Loss: 0.0944, Val Hits: 51.88%, Test Hits: 59.11%
# Epoch: 075, Loss: 0.0951, Val Hits: 51.88%, Test Hits: 57.08%
# Epoch: 076, Loss: 0.0941, Val Hits: 52.32%, Test Hits: 57.63%
# Epoch: 077, Loss: 0.0943, Val Hits: 57.59%, Test Hits: 62.65%
# Epoch: 078, Loss: 0.0947, Val Hits: 52.06%, Test Hits: 62.22%
# Epoch: 079, Loss: 0.0940, Val Hits: 52.15%, Test Hits: 56.81%
# Epoch: 080, Loss: 0.0941, Val Hits: 48.73%, Test Hits: 59.71%
# Epoch: 081, Loss: 0.0941, Val Hits: 52.40%, Test Hits: 61.19%
# Epoch: 082, Loss: 0.0941, Val Hits: 51.40%, Test Hits: 57.83%
# Epoch: 083, Loss: 0.0935, Val Hits: 51.44%, Test Hits: 58.18%
# Epoch: 084, Loss: 0.0938, Val Hits: 50.15%, Test Hits: 59.17%
# Epoch: 085, Loss: 0.0934, Val Hits: 50.97%, Test Hits: 59.57%
# Epoch: 086, Loss: 0.0932, Val Hits: 54.00%, Test Hits: 59.54%
# Epoch: 087, Loss: 0.0926, Val Hits: 52.61%, Test Hits: 59.25%
# Epoch: 088, Loss: 0.0929, Val Hits: 50.74%, Test Hits: 56.77%
# Epoch: 089, Loss: 0.0922, Val Hits: 54.53%, Test Hits: 52.77%
# Epoch: 090, Loss: 0.0926, Val Hits: 56.07%, Test Hits: 61.28%
# Epoch: 091, Loss: 0.0923, Val Hits: 55.12%, Test Hits: 60.08%
# Epoch: 092, Loss: 0.0922, Val Hits: 57.67%, Test Hits: 63.15%
# Epoch: 093, Loss: 0.0922, Val Hits: 55.23%, Test Hits: 61.96%
# Epoch: 094, Loss: 0.0917, Val Hits: 52.61%, Test Hits: 59.15%
# Epoch: 095, Loss: 0.0918, Val Hits: 57.35%, Test Hits: 60.34%
# Epoch: 096, Loss: 0.0920, Val Hits: 52.70%, Test Hits: 57.96%
# Epoch: 097, Loss: 0.0913, Val Hits: 55.55%, Test Hits: 57.01%
# Epoch: 098, Loss: 0.0918, Val Hits: 52.57%, Test Hits: 55.52%
# Epoch: 099, Loss: 0.0915, Val Hits: 56.31%, Test Hits: 57.93%
# Epoch: 100, Loss: 0.0918, Val Hits: 55.73%, Test Hits: 63.21%
# Epoch: 101, Loss: 0.0911, Val Hits: 50.23%, Test Hits: 55.37%
# Epoch: 102, Loss: 0.0916, Val Hits: 55.66%, Test Hits: 55.93%
# Epoch: 103, Loss: 0.0907, Val Hits: 53.77%, Test Hits: 59.93%
# Epoch: 104, Loss: 0.0911, Val Hits: 56.33%, Test Hits: 63.09%
# Epoch: 105, Loss: 0.0905, Val Hits: 57.16%, Test Hits: 63.63%
# Epoch: 106, Loss: 0.0909, Val Hits: 54.39%, Test Hits: 62.91%
# Epoch: 107, Loss: 0.0901, Val Hits: 55.44%, Test Hits: 63.78%
# Epoch: 108, Loss: 0.0909, Val Hits: 55.26%, Test Hits: 61.63%
# Epoch: 109, Loss: 0.0906, Val Hits: 58.04%, Test Hits: 62.77%
# Epoch: 110, Loss: 0.0905, Val Hits: 56.36%, Test Hits: 58.77%
# Epoch: 111, Loss: 0.0903, Val Hits: 54.64%, Test Hits: 59.34%
# Epoch: 112, Loss: 0.0902, Val Hits: 53.41%, Test Hits: 63.07%
# Epoch: 113, Loss: 0.0898, Val Hits: 57.75%, Test Hits: 65.77%
# Epoch: 114, Loss: 0.0900, Val Hits: 55.15%, Test Hits: 60.88%
# Epoch: 115, Loss: 0.0900, Val Hits: 57.18%, Test Hits: 64.38%
# Epoch: 116, Loss: 0.0898, Val Hits: 56.74%, Test Hits: 60.27%
# Epoch: 117, Loss: 0.0894, Val Hits: 55.41%, Test Hits: 62.18%
# Epoch: 118, Loss: 0.0899, Val Hits: 55.25%, Test Hits: 63.16%
# Epoch: 119, Loss: 0.0897, Val Hits: 56.99%, Test Hits: 63.29%
# Epoch: 120, Loss: 0.0898, Val Hits: 57.86%, Test Hits: 64.20%
# Epoch: 121, Loss: 0.0888, Val Hits: 58.15%, Test Hits: 66.02%
# Epoch: 122, Loss: 0.0892, Val Hits: 57.26%, Test Hits: 66.71%
# Epoch: 123, Loss: 0.0895, Val Hits: 58.67%, Test Hits: 68.57%
# Epoch: 124, Loss: 0.0891, Val Hits: 57.91%, Test Hits: 63.28%
# Epoch: 125, Loss: 0.0889, Val Hits: 57.21%, Test Hits: 64.08%
# Epoch: 126, Loss: 0.0889, Val Hits: 55.59%, Test Hits: 67.06%
# Epoch: 127, Loss: 0.0890, Val Hits: 55.88%, Test Hits: 62.63%
# Epoch: 128, Loss: 0.0890, Val Hits: 58.14%, Test Hits: 66.81%
# Epoch: 129, Loss: 0.0896, Val Hits: 58.42%, Test Hits: 68.46%
# Epoch: 130, Loss: 0.0887, Val Hits: 61.52%, Test Hits: 68.87%
# Epoch: 131, Loss: 0.0890, Val Hits: 57.66%, Test Hits: 65.87%
# Epoch: 132, Loss: 0.0888, Val Hits: 55.03%, Test Hits: 68.44%
# Epoch: 133, Loss: 0.0886, Val Hits: 58.64%, Test Hits: 69.30%
# Epoch: 134, Loss: 0.0887, Val Hits: 59.40%, Test Hits: 67.82%
# Epoch: 135, Loss: 0.0883, Val Hits: 59.31%, Test Hits: 68.95%
# Epoch: 136, Loss: 0.0887, Val Hits: 59.13%, Test Hits: 67.82%
# Epoch: 137, Loss: 0.0884, Val Hits: 58.44%, Test Hits: 69.11%
# Epoch: 138, Loss: 0.0883, Val Hits: 59.43%, Test Hits: 66.85%
# Epoch: 139, Loss: 0.0887, Val Hits: 59.41%, Test Hits: 68.35%
# Epoch: 140, Loss: 0.0883, Val Hits: 61.28%, Test Hits: 70.24%
# Epoch: 141, Loss: 0.0881, Val Hits: 59.28%, Test Hits: 69.33%
# Epoch: 142, Loss: 0.0877, Val Hits: 56.49%, Test Hits: 64.09%
# Epoch: 143, Loss: 0.0875, Val Hits: 59.58%, Test Hits: 67.65%
# Epoch: 144, Loss: 0.0886, Val Hits: 57.89%, Test Hits: 66.13%
# Epoch: 145, Loss: 0.0879, Val Hits: 59.42%, Test Hits: 71.96%
# Epoch: 146, Loss: 0.0878, Val Hits: 55.49%, Test Hits: 66.68%
# Epoch: 147, Loss: 0.0881, Val Hits: 57.79%, Test Hits: 68.02%
# Epoch: 148, Loss: 0.0878, Val Hits: 59.25%, Test Hits: 67.28%
# Epoch: 149, Loss: 0.0879, Val Hits: 57.07%, Test Hits: 69.33%
# Epoch: 150, Loss: 0.0879, Val Hits: 61.35%, Test Hits: 69.14%
# Epoch: 151, Loss: 0.0876, Val Hits: 61.13%, Test Hits: 67.25%
# Epoch: 152, Loss: 0.0872, Val Hits: 59.36%, Test Hits: 72.85%
# Epoch: 153, Loss: 0.0871, Val Hits: 58.87%, Test Hits: 68.23%
# Epoch: 154, Loss: 0.0871, Val Hits: 58.83%, Test Hits: 70.98%
# Epoch: 155, Loss: 0.0872, Val Hits: 62.17%, Test Hits: 67.69%
# Epoch: 156, Loss: 0.0877, Val Hits: 59.35%, Test Hits: 66.46%
# Epoch: 157, Loss: 0.0868, Val Hits: 62.84%, Test Hits: 66.84%
# Epoch: 158, Loss: 0.0870, Val Hits: 57.78%, Test Hits: 68.72%
# Epoch: 159, Loss: 0.0875, Val Hits: 59.38%, Test Hits: 68.63%
# Epoch: 160, Loss: 0.0868, Val Hits: 60.03%, Test Hits: 69.97%
# Epoch: 161, Loss: 0.0876, Val Hits: 61.84%, Test Hits: 71.94%
# Epoch: 162, Loss: 0.0868, Val Hits: 61.97%, Test Hits: 69.33%
# Epoch: 163, Loss: 0.0865, Val Hits: 63.05%, Test Hits: 69.17%
# Epoch: 164, Loss: 0.0870, Val Hits: 62.10%, Test Hits: 68.68%
# Epoch: 165, Loss: 0.0868, Val Hits: 61.17%, Test Hits: 70.90%
# Epoch: 166, Loss: 0.0862, Val Hits: 62.18%, Test Hits: 69.65%
# Epoch: 167, Loss: 0.0867, Val Hits: 66.12%, Test Hits: 71.04%
# Epoch: 168, Loss: 0.0865, Val Hits: 62.99%, Test Hits: 70.77%
# Epoch: 169, Loss: 0.0870, Val Hits: 60.02%, Test Hits: 70.73%
# Epoch: 170, Loss: 0.0861, Val Hits: 61.86%, Test Hits: 65.79%
# Epoch: 171, Loss: 0.0871, Val Hits: 57.23%, Test Hits: 65.55%
# Epoch: 172, Loss: 0.0862, Val Hits: 59.03%, Test Hits: 71.40%
# Epoch: 173, Loss: 0.0865, Val Hits: 57.81%, Test Hits: 64.17%
# Epoch: 174, Loss: 0.0861, Val Hits: 60.73%, Test Hits: 66.34%
# Epoch: 175, Loss: 0.0859, Val Hits: 62.12%, Test Hits: 67.35%
# Epoch: 176, Loss: 0.0863, Val Hits: 62.99%, Test Hits: 69.90%
# Epoch: 177, Loss: 0.0864, Val Hits: 61.22%, Test Hits: 65.67%
# Epoch: 178, Loss: 0.0859, Val Hits: 61.58%, Test Hits: 73.66%
# Epoch: 179, Loss: 0.0859, Val Hits: 61.07%, Test Hits: 69.60%
# Epoch: 180, Loss: 0.0855, Val Hits: 60.27%, Test Hits: 68.52%
# Epoch: 181, Loss: 0.0866, Val Hits: 62.38%, Test Hits: 70.98%
# Epoch: 182, Loss: 0.0863, Val Hits: 61.95%, Test Hits: 69.41%
# Epoch: 183, Loss: 0.0860, Val Hits: 60.92%, Test Hits: 74.61%
# Epoch: 184, Loss: 0.0860, Val Hits: 62.37%, Test Hits: 73.65%
# Epoch: 185, Loss: 0.0864, Val Hits: 61.67%, Test Hits: 71.59%
# Epoch: 186, Loss: 0.0863, Val Hits: 55.88%, Test Hits: 58.88%
# Epoch: 187, Loss: 0.0857, Val Hits: 62.06%, Test Hits: 68.99%
# Epoch: 188, Loss: 0.0859, Val Hits: 59.62%, Test Hits: 68.19%
# Epoch: 189, Loss: 0.0863, Val Hits: 61.12%, Test Hits: 71.96%
# Epoch: 190, Loss: 0.0857, Val Hits: 57.84%, Test Hits: 66.49%
# Epoch: 191, Loss: 0.0857, Val Hits: 58.38%, Test Hits: 66.36%
# Epoch: 192, Loss: 0.0857, Val Hits: 61.28%, Test Hits: 70.70%
# Epoch: 193, Loss: 0.0856, Val Hits: 63.47%, Test Hits: 71.26%
# Epoch: 194, Loss: 0.0858, Val Hits: 63.78%, Test Hits: 72.74%
# Epoch: 195, Loss: 0.0853, Val Hits: 62.18%, Test Hits: 71.56%
# Epoch: 196, Loss: 0.0858, Val Hits: 58.84%, Test Hits: 61.61%
# Epoch: 197, Loss: 0.0850, Val Hits: 63.51%, Test Hits: 72.29%
# Epoch: 198, Loss: 0.0852, Val Hits: 61.85%, Test Hits: 67.48%
# Epoch: 199, Loss: 0.0850, Val Hits: 61.28%, Test Hits: 66.09%
# Epoch: 200, Loss: 0.0854, Val Hits: 60.03%, Test Hits: 67.84%
# Epoch: 201, Loss: 0.0854, Val Hits: 62.76%, Test Hits: 71.26%
# Epoch: 202, Loss: 0.0855, Val Hits: 60.76%, Test Hits: 69.51%
# Epoch: 203, Loss: 0.0851, Val Hits: 64.76%, Test Hits: 74.18%
# Epoch: 204, Loss: 0.0850, Val Hits: 61.91%, Test Hits: 70.77%
# Epoch: 205, Loss: 0.0851, Val Hits: 58.25%, Test Hits: 63.87%
# Epoch: 206, Loss: 0.0849, Val Hits: 62.72%, Test Hits: 69.24%
# Epoch: 207, Loss: 0.0851, Val Hits: 66.47%, Test Hits: 74.97%
# Epoch: 208, Loss: 0.0853, Val Hits: 65.51%, Test Hits: 67.91%
# Epoch: 209, Loss: 0.0850, Val Hits: 64.92%, Test Hits: 70.88%
# Epoch: 210, Loss: 0.0851, Val Hits: 64.43%, Test Hits: 72.30%
# Epoch: 211, Loss: 0.0858, Val Hits: 62.29%, Test Hits: 69.03%
# Epoch: 212, Loss: 0.0854, Val Hits: 62.18%, Test Hits: 67.17%
# Epoch: 213, Loss: 0.0849, Val Hits: 62.96%, Test Hits: 69.75%
# Epoch: 214, Loss: 0.0844, Val Hits: 64.37%, Test Hits: 71.81%
# Epoch: 215, Loss: 0.0852, Val Hits: 59.59%, Test Hits: 68.10%
# Epoch: 216, Loss: 0.0852, Val Hits: 61.33%, Test Hits: 71.16%
# Epoch: 217, Loss: 0.0853, Val Hits: 63.04%, Test Hits: 71.83%
# Epoch: 218, Loss: 0.0844, Val Hits: 59.91%, Test Hits: 66.98%
# Epoch: 219, Loss: 0.0848, Val Hits: 64.17%, Test Hits: 73.36%
# Epoch: 220, Loss: 0.0848, Val Hits: 61.04%, Test Hits: 72.61%
# Epoch: 221, Loss: 0.0850, Val Hits: 61.55%, Test Hits: 72.17%
# Epoch: 222, Loss: 0.0852, Val Hits: 64.33%, Test Hits: 72.07%
# Epoch: 223, Loss: 0.0852, Val Hits: 60.34%, Test Hits: 65.81%
# Epoch: 224, Loss: 0.0853, Val Hits: 63.53%, Test Hits: 70.55%
# Epoch: 225, Loss: 0.0844, Val Hits: 63.59%, Test Hits: 71.44%
# Epoch: 226, Loss: 0.0840, Val Hits: 58.15%, Test Hits: 72.52%
# Epoch: 227, Loss: 0.0846, Val Hits: 62.70%, Test Hits: 71.59%
# Epoch: 228, Loss: 0.0841, Val Hits: 64.16%, Test Hits: 74.11%
# Epoch: 229, Loss: 0.0846, Val Hits: 63.96%, Test Hits: 70.99%
# Epoch: 230, Loss: 0.0846, Val Hits: 63.01%, Test Hits: 68.08%
# Epoch: 231, Loss: 0.0842, Val Hits: 64.55%, Test Hits: 73.16%
# Epoch: 232, Loss: 0.0848, Val Hits: 66.51%, Test Hits: 77.00%
# Epoch: 233, Loss: 0.0841, Val Hits: 61.27%, Test Hits: 69.22%
# Epoch: 234, Loss: 0.0847, Val Hits: 63.28%, Test Hits: 75.87%
# Epoch: 235, Loss: 0.0843, Val Hits: 63.99%, Test Hits: 74.90%
# Epoch: 236, Loss: 0.0843, Val Hits: 63.39%, Test Hits: 73.86%
# Epoch: 237, Loss: 0.0845, Val Hits: 61.67%, Test Hits: 71.41%
# Epoch: 238, Loss: 0.0839, Val Hits: 61.57%, Test Hits: 69.48%
# Epoch: 239, Loss: 0.0838, Val Hits: 63.83%, Test Hits: 73.19%
# Epoch: 240, Loss: 0.0844, Val Hits: 65.22%, Test Hits: 73.25%
# Epoch: 241, Loss: 0.0841, Val Hits: 65.41%, Test Hits: 72.52%
# Epoch: 242, Loss: 0.0842, Val Hits: 43.45%, Test Hits: 51.19%
# Epoch: 243, Loss: 0.0835, Val Hits: 63.82%, Test Hits: 74.79%
# Epoch: 244, Loss: 0.0842, Val Hits: 63.66%, Test Hits: 72.65%
# Epoch: 245, Loss: 0.0842, Val Hits: 64.95%, Test Hits: 74.71%
# Epoch: 246, Loss: 0.0838, Val Hits: 39.60%, Test Hits: 57.85%
# Epoch: 247, Loss: 0.0843, Val Hits: 65.09%, Test Hits: 72.83%
# Epoch: 248, Loss: 0.0842, Val Hits: 65.77%, Test Hits: 74.47%
# Epoch: 249, Loss: 0.0840, Val Hits: 63.84%, Test Hits: 76.64%
# Epoch: 250, Loss: 0.0840, Val Hits: 61.51%, Test Hits: 73.68%
# Epoch: 251, Loss: 0.0838, Val Hits: 63.48%, Test Hits: 77.24%
# Epoch: 252, Loss: 0.0839, Val Hits: 57.87%, Test Hits: 65.20%
# Epoch: 253, Loss: 0.0843, Val Hits: 62.98%, Test Hits: 74.94%
# Epoch: 254, Loss: 0.0834, Val Hits: 62.87%, Test Hits: 72.75%
# Epoch: 255, Loss: 0.0843, Val Hits: 64.81%, Test Hits: 78.67%
# Epoch: 256, Loss: 0.0838, Val Hits: 64.38%, Test Hits: 75.87%
# Epoch: 257, Loss: 0.0841, Val Hits: 65.16%, Test Hits: 74.49%
# Epoch: 258, Loss: 0.0836, Val Hits: 63.25%, Test Hits: 72.95%
# Epoch: 259, Loss: 0.0829, Val Hits: 63.41%, Test Hits: 71.41%
# Epoch: 260, Loss: 0.0840, Val Hits: 65.00%, Test Hits: 71.86%
# Epoch: 261, Loss: 0.0834, Val Hits: 66.25%, Test Hits: 72.00%
# Epoch: 262, Loss: 0.0839, Val Hits: 66.18%, Test Hits: 72.46%
# Epoch: 263, Loss: 0.0836, Val Hits: 65.00%, Test Hits: 72.73%
# Epoch: 264, Loss: 0.0840, Val Hits: 62.77%, Test Hits: 70.05%
# Epoch: 265, Loss: 0.0837, Val Hits: 66.65%, Test Hits: 70.00%
# Epoch: 266, Loss: 0.0839, Val Hits: 66.19%, Test Hits: 74.28%
# Epoch: 267, Loss: 0.0835, Val Hits: 64.72%, Test Hits: 72.50%
# Epoch: 268, Loss: 0.0833, Val Hits: 66.22%, Test Hits: 72.55%
# Epoch: 269, Loss: 0.0837, Val Hits: 65.65%, Test Hits: 76.52%
# Epoch: 270, Loss: 0.0836, Val Hits: 66.52%, Test Hits: 73.69%
# Epoch: 271, Loss: 0.0839, Val Hits: 56.99%, Test Hits: 66.73%
# Epoch: 272, Loss: 0.0842, Val Hits: 65.06%, Test Hits: 75.64%
# Epoch: 273, Loss: 0.0833, Val Hits: 65.05%, Test Hits: 71.50%
# Epoch: 274, Loss: 0.0833, Val Hits: 61.36%, Test Hits: 65.95%
# Epoch: 275, Loss: 0.0836, Val Hits: 64.78%, Test Hits: 70.50%
# Epoch: 276, Loss: 0.0835, Val Hits: 64.10%, Test Hits: 72.62%
# Epoch: 277, Loss: 0.0839, Val Hits: 65.29%, Test Hits: 75.57%
# Epoch: 278, Loss: 0.0834, Val Hits: 66.34%, Test Hits: 75.14%
# Epoch: 279, Loss: 0.0829, Val Hits: 62.64%, Test Hits: 73.29%
# Epoch: 280, Loss: 0.0833, Val Hits: 67.55%, Test Hits: 75.86%
# Epoch: 281, Loss: 0.0831, Val Hits: 64.84%, Test Hits: 70.49%
# Epoch: 282, Loss: 0.0830, Val Hits: 66.26%, Test Hits: 66.67%
# Epoch: 283, Loss: 0.0832, Val Hits: 65.21%, Test Hits: 73.54%
# Epoch: 284, Loss: 0.0833, Val Hits: 62.33%, Test Hits: 72.74%
# Epoch: 285, Loss: 0.0838, Val Hits: 66.47%, Test Hits: 71.51%
# Epoch: 286, Loss: 0.0837, Val Hits: 65.68%, Test Hits: 75.20%
# Epoch: 287, Loss: 0.0835, Val Hits: 65.49%, Test Hits: 73.62%
# Epoch: 288, Loss: 0.0831, Val Hits: 66.78%, Test Hits: 78.20%
# Epoch: 289, Loss: 0.0833, Val Hits: 55.56%, Test Hits: 62.75%
# Epoch: 290, Loss: 0.0828, Val Hits: 65.54%, Test Hits: 76.67%
# Epoch: 291, Loss: 0.0825, Val Hits: 62.52%, Test Hits: 70.55%
# Epoch: 292, Loss: 0.0834, Val Hits: 66.80%, Test Hits: 76.17%
# Epoch: 293, Loss: 0.0838, Val Hits: 66.42%, Test Hits: 78.11%
# Epoch: 294, Loss: 0.0826, Val Hits: 63.83%, Test Hits: 72.25%
# Epoch: 295, Loss: 0.0833, Val Hits: 66.31%, Test Hits: 76.55%
# Epoch: 296, Loss: 0.0829, Val Hits: 65.20%, Test Hits: 70.88%
# Epoch: 297, Loss: 0.0830, Val Hits: 66.23%, Test Hits: 73.25%
# Epoch: 298, Loss: 0.0828, Val Hits: 64.46%, Test Hits: 71.18%
# Epoch: 299, Loss: 0.0830, Val Hits: 65.48%, Test Hits: 74.87%
# Epoch: 300, Loss: 0.0832, Val Hits: 66.38%, Test Hits: 74.62%
# Epoch: 301, Loss: 0.0832, Val Hits: 65.18%, Test Hits: 78.74%
# Epoch: 302, Loss: 0.0826, Val Hits: 66.18%, Test Hits: 75.72%
# Epoch: 303, Loss: 0.0830, Val Hits: 67.32%, Test Hits: 74.57%
# Epoch: 304, Loss: 0.0830, Val Hits: 66.03%, Test Hits: 74.48%
# Epoch: 305, Loss: 0.0825, Val Hits: 64.55%, Test Hits: 76.34%
# Epoch: 306, Loss: 0.0834, Val Hits: 64.91%, Test Hits: 70.04%
# Epoch: 307, Loss: 0.0825, Val Hits: 66.67%, Test Hits: 77.72%
# Epoch: 308, Loss: 0.0826, Val Hits: 67.06%, Test Hits: 75.23%
# Epoch: 309, Loss: 0.0832, Val Hits: 66.25%, Test Hits: 74.62%
# Epoch: 310, Loss: 0.0821, Val Hits: 66.18%, Test Hits: 76.90%
# Epoch: 311, Loss: 0.0821, Val Hits: 66.41%, Test Hits: 76.09%
# Epoch: 312, Loss: 0.0830, Val Hits: 64.89%, Test Hits: 74.58%
# Epoch: 313, Loss: 0.0827, Val Hits: 66.33%, Test Hits: 79.23%
# Epoch: 314, Loss: 0.0827, Val Hits: 65.88%, Test Hits: 76.47%
# Epoch: 315, Loss: 0.0830, Val Hits: 65.94%, Test Hits: 76.54%
# Epoch: 316, Loss: 0.0828, Val Hits: 63.32%, Test Hits: 77.78%
# Epoch: 317, Loss: 0.0826, Val Hits: 64.67%, Test Hits: 74.30%
# Epoch: 318, Loss: 0.0827, Val Hits: 66.93%, Test Hits: 74.57%
# Epoch: 319, Loss: 0.0821, Val Hits: 66.05%, Test Hits: 72.64%
# Epoch: 320, Loss: 0.0826, Val Hits: 66.19%, Test Hits: 78.12%
# Epoch: 321, Loss: 0.0830, Val Hits: 65.58%, Test Hits: 75.21%
# Epoch: 322, Loss: 0.0822, Val Hits: 66.40%, Test Hits: 77.76%
# Epoch: 323, Loss: 0.0823, Val Hits: 65.72%, Test Hits: 74.97%
# Epoch: 324, Loss: 0.0820, Val Hits: 65.87%, Test Hits: 78.39%
# Epoch: 325, Loss: 0.0825, Val Hits: 63.62%, Test Hits: 76.56%
# Epoch: 326, Loss: 0.0824, Val Hits: 67.10%, Test Hits: 78.50%
# Epoch: 327, Loss: 0.0823, Val Hits: 63.79%, Test Hits: 74.04%
# Epoch: 328, Loss: 0.0828, Val Hits: 65.79%, Test Hits: 80.77%
# Epoch: 329, Loss: 0.0826, Val Hits: 64.07%, Test Hits: 79.18%
# Epoch: 330, Loss: 0.0821, Val Hits: 65.40%, Test Hits: 77.46%
# Epoch: 331, Loss: 0.0821, Val Hits: 65.27%, Test Hits: 75.62%
# Epoch: 332, Loss: 0.0826, Val Hits: 65.38%, Test Hits: 75.57%
# Epoch: 333, Loss: 0.0820, Val Hits: 63.08%, Test Hits: 72.19%
# Epoch: 334, Loss: 0.0825, Val Hits: 59.20%, Test Hits: 70.77%
# Epoch: 335, Loss: 0.0823, Val Hits: 65.87%, Test Hits: 76.90%
# Epoch: 336, Loss: 0.0822, Val Hits: 65.16%, Test Hits: 78.53%
# Epoch: 337, Loss: 0.0823, Val Hits: 65.02%, Test Hits: 77.29%
# Epoch: 338, Loss: 0.0824, Val Hits: 66.17%, Test Hits: 78.42%
# Epoch: 339, Loss: 0.0819, Val Hits: 65.39%, Test Hits: 74.17%
# Epoch: 340, Loss: 0.0817, Val Hits: 64.69%, Test Hits: 76.66%
# Epoch: 341, Loss: 0.0824, Val Hits: 66.27%, Test Hits: 75.78%
# Epoch: 342, Loss: 0.0818, Val Hits: 58.01%, Test Hits: 68.59%
# Epoch: 343, Loss: 0.0824, Val Hits: 64.30%, Test Hits: 77.14%
# Epoch: 344, Loss: 0.0822, Val Hits: 66.05%, Test Hits: 75.52%
# Epoch: 345, Loss: 0.0820, Val Hits: 67.10%, Test Hits: 78.84%
# Epoch: 346, Loss: 0.0820, Val Hits: 66.12%, Test Hits: 80.26%
# Epoch: 347, Loss: 0.0825, Val Hits: 48.73%, Test Hits: 55.60%
# Epoch: 348, Loss: 0.0826, Val Hits: 66.38%, Test Hits: 75.85%
# Epoch: 349, Loss: 0.0823, Val Hits: 66.37%, Test Hits: 77.29%
# Epoch: 350, Loss: 0.0823, Val Hits: 67.94%, Test Hits: 78.95%
# Epoch: 351, Loss: 0.0819, Val Hits: 66.84%, Test Hits: 78.80%
# Epoch: 352, Loss: 0.0818, Val Hits: 66.37%, Test Hits: 79.23%
# Epoch: 353, Loss: 0.0816, Val Hits: 67.66%, Test Hits: 78.44%
# Epoch: 354, Loss: 0.0818, Val Hits: 63.36%, Test Hits: 73.76%
# Epoch: 355, Loss: 0.0817, Val Hits: 65.72%, Test Hits: 77.65%
# Epoch: 356, Loss: 0.0818, Val Hits: 65.21%, Test Hits: 76.82%
# Epoch: 357, Loss: 0.0822, Val Hits: 65.94%, Test Hits: 77.56%
# Epoch: 358, Loss: 0.0816, Val Hits: 66.67%, Test Hits: 78.54%
# Epoch: 359, Loss: 0.0819, Val Hits: 67.18%, Test Hits: 79.62%
# Epoch: 360, Loss: 0.0824, Val Hits: 63.43%, Test Hits: 75.58%
# Epoch: 361, Loss: 0.0822, Val Hits: 67.35%, Test Hits: 76.69%
# Epoch: 362, Loss: 0.0821, Val Hits: 66.41%, Test Hits: 76.24%
# Epoch: 363, Loss: 0.0819, Val Hits: 66.15%, Test Hits: 79.96%
# Epoch: 364, Loss: 0.0813, Val Hits: 66.04%, Test Hits: 74.75%
# Epoch: 365, Loss: 0.0825, Val Hits: 65.99%, Test Hits: 75.57%
# Epoch: 366, Loss: 0.0818, Val Hits: 66.17%, Test Hits: 75.70%
# Epoch: 367, Loss: 0.0818, Val Hits: 65.25%, Test Hits: 77.03%
# Epoch: 368, Loss: 0.0819, Val Hits: 64.86%, Test Hits: 75.42%
# Epoch: 369, Loss: 0.0814, Val Hits: 62.34%, Test Hits: 77.36%
# Epoch: 370, Loss: 0.0820, Val Hits: 65.54%, Test Hits: 79.09%
# Epoch: 371, Loss: 0.0820, Val Hits: 65.13%, Test Hits: 78.11%
# Epoch: 372, Loss: 0.0817, Val Hits: 67.37%, Test Hits: 78.35%
# Epoch: 373, Loss: 0.0819, Val Hits: 66.49%, Test Hits: 78.07%
# Epoch: 374, Loss: 0.0814, Val Hits: 65.04%, Test Hits: 75.25%
# Epoch: 375, Loss: 0.0817, Val Hits: 66.80%, Test Hits: 77.22%
# Epoch: 376, Loss: 0.0817, Val Hits: 66.52%, Test Hits: 76.93%
# Epoch: 377, Loss: 0.0819, Val Hits: 66.82%, Test Hits: 79.53%
# Epoch: 378, Loss: 0.0817, Val Hits: 65.88%, Test Hits: 79.01%
# Epoch: 379, Loss: 0.0818, Val Hits: 63.69%, Test Hits: 75.43%
# Epoch: 380, Loss: 0.0816, Val Hits: 66.72%, Test Hits: 75.09%
# Epoch: 381, Loss: 0.0816, Val Hits: 66.35%, Test Hits: 77.63%
# Epoch: 382, Loss: 0.0821, Val Hits: 66.75%, Test Hits: 75.51%
# Epoch: 383, Loss: 0.0819, Val Hits: 67.37%, Test Hits: 78.10%
# Epoch: 384, Loss: 0.0820, Val Hits: 62.85%, Test Hits: 73.67%
# Epoch: 385, Loss: 0.0814, Val Hits: 63.38%, Test Hits: 72.10%
# Epoch: 386, Loss: 0.0813, Val Hits: 67.12%, Test Hits: 78.78%
# Epoch: 387, Loss: 0.0818, Val Hits: 66.22%, Test Hits: 74.96%
# Epoch: 388, Loss: 0.0813, Val Hits: 61.33%, Test Hits: 70.94%
# Epoch: 389, Loss: 0.0813, Val Hits: 67.30%, Test Hits: 78.99%
# Epoch: 390, Loss: 0.0817, Val Hits: 65.79%, Test Hits: 76.83%
# Epoch: 391, Loss: 0.0817, Val Hits: 66.24%, Test Hits: 78.37%
# Epoch: 392, Loss: 0.0812, Val Hits: 67.16%, Test Hits: 74.97%
# Epoch: 393, Loss: 0.0813, Val Hits: 65.87%, Test Hits: 79.66%
# Epoch: 394, Loss: 0.0818, Val Hits: 66.60%, Test Hits: 77.43%
# Epoch: 395, Loss: 0.0813, Val Hits: 65.46%, Test Hits: 75.66%
# Epoch: 396, Loss: 0.0813, Val Hits: 65.53%, Test Hits: 73.16%
# Epoch: 397, Loss: 0.0817, Val Hits: 66.75%, Test Hits: 78.00%
# Epoch: 398, Loss: 0.0815, Val Hits: 65.98%, Test Hits: 76.63%
# Epoch: 399, Loss: 0.0813, Val Hits: 65.07%, Test Hits: 77.22%
# Epoch: 400, Loss: 0.0809, Val Hits: 66.41%, Test Hits: 76.59%
# Final model:
# Epoch: 350, Val Hits: 67.94%, Test Hits: 78.95%
# Run 1 done.
# Epoch: 001, Loss: 0.4185, Val Hits: 0.10%, Test Hits: 0.07%
# Epoch: 002, Loss: 0.3317, Val Hits: 17.47%, Test Hits: 14.75%
# Epoch: 003, Loss: 0.2844, Val Hits: 6.51%, Test Hits: 4.85%
# Epoch: 004, Loss: 0.2523, Val Hits: 8.98%, Test Hits: 8.24%
# Epoch: 005, Loss: 0.2297, Val Hits: 9.02%, Test Hits: 4.89%
# Epoch: 006, Loss: 0.2131, Val Hits: 8.28%, Test Hits: 3.06%
# Epoch: 007, Loss: 0.1984, Val Hits: 8.56%, Test Hits: 2.56%
# Epoch: 008, Loss: 0.1857, Val Hits: 9.79%, Test Hits: 5.32%
# Epoch: 009, Loss: 0.1750, Val Hits: 17.23%, Test Hits: 14.93%
# Epoch: 010, Loss: 0.1666, Val Hits: 17.45%, Test Hits: 10.83%
# Epoch: 011, Loss: 0.1593, Val Hits: 13.82%, Test Hits: 14.88%
# Epoch: 012, Loss: 0.1528, Val Hits: 15.44%, Test Hits: 13.83%
# Epoch: 013, Loss: 0.1470, Val Hits: 18.21%, Test Hits: 14.35%
# Epoch: 014, Loss: 0.1425, Val Hits: 16.95%, Test Hits: 14.51%
# Epoch: 015, Loss: 0.1386, Val Hits: 21.10%, Test Hits: 15.98%
# Epoch: 016, Loss: 0.1350, Val Hits: 23.31%, Test Hits: 21.89%
# Epoch: 017, Loss: 0.1320, Val Hits: 25.11%, Test Hits: 23.16%
# Epoch: 018, Loss: 0.1291, Val Hits: 27.21%, Test Hits: 24.82%
# Epoch: 019, Loss: 0.1268, Val Hits: 27.78%, Test Hits: 26.66%
# Epoch: 020, Loss: 0.1244, Val Hits: 30.91%, Test Hits: 30.04%
# Epoch: 021, Loss: 0.1216, Val Hits: 28.10%, Test Hits: 27.47%
# Epoch: 022, Loss: 0.1202, Val Hits: 31.80%, Test Hits: 32.01%
# Epoch: 023, Loss: 0.1185, Val Hits: 27.68%, Test Hits: 25.87%
# Epoch: 024, Loss: 0.1174, Val Hits: 29.28%, Test Hits: 27.62%
# Epoch: 025, Loss: 0.1149, Val Hits: 36.01%, Test Hits: 33.25%
# Epoch: 026, Loss: 0.1140, Val Hits: 37.46%, Test Hits: 29.48%
# Epoch: 027, Loss: 0.1133, Val Hits: 41.69%, Test Hits: 34.70%
# Epoch: 028, Loss: 0.1124, Val Hits: 39.95%, Test Hits: 32.18%
# Epoch: 029, Loss: 0.1110, Val Hits: 39.55%, Test Hits: 38.33%
# Epoch: 030, Loss: 0.1104, Val Hits: 41.50%, Test Hits: 41.53%
# Epoch: 031, Loss: 0.1098, Val Hits: 39.34%, Test Hits: 40.41%
# Epoch: 032, Loss: 0.1089, Val Hits: 41.42%, Test Hits: 44.70%
# Epoch: 033, Loss: 0.1081, Val Hits: 41.39%, Test Hits: 36.87%
# Epoch: 034, Loss: 0.1072, Val Hits: 44.84%, Test Hits: 46.62%
# Epoch: 035, Loss: 0.1070, Val Hits: 43.03%, Test Hits: 41.91%
# Epoch: 036, Loss: 0.1064, Val Hits: 43.33%, Test Hits: 45.33%
# Epoch: 037, Loss: 0.1056, Val Hits: 47.81%, Test Hits: 46.67%
# Epoch: 038, Loss: 0.1044, Val Hits: 47.01%, Test Hits: 49.81%
# Epoch: 039, Loss: 0.1047, Val Hits: 39.75%, Test Hits: 45.32%
# Epoch: 040, Loss: 0.1040, Val Hits: 41.91%, Test Hits: 45.63%
# Epoch: 041, Loss: 0.1026, Val Hits: 43.43%, Test Hits: 43.93%
# Epoch: 042, Loss: 0.1032, Val Hits: 50.14%, Test Hits: 46.66%
# Epoch: 043, Loss: 0.1027, Val Hits: 47.46%, Test Hits: 45.76%
# Epoch: 044, Loss: 0.1017, Val Hits: 48.93%, Test Hits: 47.62%
# Epoch: 045, Loss: 0.1015, Val Hits: 47.85%, Test Hits: 49.84%
# Epoch: 046, Loss: 0.1011, Val Hits: 42.85%, Test Hits: 44.84%
# Epoch: 047, Loss: 0.1005, Val Hits: 48.76%, Test Hits: 53.91%
# Epoch: 048, Loss: 0.1005, Val Hits: 43.14%, Test Hits: 47.62%
# Epoch: 049, Loss: 0.1004, Val Hits: 51.58%, Test Hits: 54.76%
# Epoch: 050, Loss: 0.1001, Val Hits: 50.63%, Test Hits: 53.54%
# Epoch: 051, Loss: 0.0996, Val Hits: 54.19%, Test Hits: 55.68%
# Epoch: 052, Loss: 0.0994, Val Hits: 47.99%, Test Hits: 50.14%
# Epoch: 053, Loss: 0.0994, Val Hits: 56.46%, Test Hits: 58.63%
# Epoch: 054, Loss: 0.0988, Val Hits: 45.66%, Test Hits: 49.56%
# Epoch: 055, Loss: 0.0986, Val Hits: 49.28%, Test Hits: 53.90%
# Epoch: 056, Loss: 0.0986, Val Hits: 50.39%, Test Hits: 58.57%
# Epoch: 057, Loss: 0.0982, Val Hits: 48.06%, Test Hits: 57.86%
# Epoch: 058, Loss: 0.0977, Val Hits: 50.73%, Test Hits: 58.16%
# Epoch: 059, Loss: 0.0977, Val Hits: 50.61%, Test Hits: 56.69%
# Epoch: 060, Loss: 0.0979, Val Hits: 52.38%, Test Hits: 60.04%
# Epoch: 061, Loss: 0.0968, Val Hits: 51.99%, Test Hits: 54.87%
# Epoch: 062, Loss: 0.0967, Val Hits: 55.50%, Test Hits: 58.78%
# Epoch: 063, Loss: 0.0966, Val Hits: 56.81%, Test Hits: 59.43%
# Epoch: 064, Loss: 0.0965, Val Hits: 57.26%, Test Hits: 62.87%
# Epoch: 065, Loss: 0.0957, Val Hits: 46.91%, Test Hits: 56.53%
# Epoch: 066, Loss: 0.0962, Val Hits: 48.81%, Test Hits: 59.69%
# Epoch: 067, Loss: 0.0956, Val Hits: 55.16%, Test Hits: 61.80%
# Epoch: 068, Loss: 0.0953, Val Hits: 54.43%, Test Hits: 60.85%
# Epoch: 069, Loss: 0.0953, Val Hits: 53.83%, Test Hits: 61.96%
# Epoch: 070, Loss: 0.0960, Val Hits: 52.56%, Test Hits: 61.29%
# Epoch: 071, Loss: 0.0947, Val Hits: 53.17%, Test Hits: 61.89%
# Epoch: 072, Loss: 0.0946, Val Hits: 56.02%, Test Hits: 65.22%
# Epoch: 073, Loss: 0.0939, Val Hits: 51.80%, Test Hits: 63.47%
# Epoch: 074, Loss: 0.0944, Val Hits: 53.47%, Test Hits: 64.57%
# Epoch: 075, Loss: 0.0943, Val Hits: 54.94%, Test Hits: 64.83%
# Epoch: 076, Loss: 0.0940, Val Hits: 55.41%, Test Hits: 63.64%
# Epoch: 077, Loss: 0.0941, Val Hits: 56.24%, Test Hits: 67.57%
# Epoch: 078, Loss: 0.0935, Val Hits: 62.02%, Test Hits: 67.78%
# Epoch: 079, Loss: 0.0936, Val Hits: 53.39%, Test Hits: 63.42%
# Epoch: 080, Loss: 0.0936, Val Hits: 54.18%, Test Hits: 62.29%
# Epoch: 081, Loss: 0.0932, Val Hits: 49.54%, Test Hits: 61.83%
# Epoch: 082, Loss: 0.0935, Val Hits: 54.37%, Test Hits: 62.95%
# Epoch: 083, Loss: 0.0927, Val Hits: 55.69%, Test Hits: 64.35%
# Epoch: 084, Loss: 0.0929, Val Hits: 56.76%, Test Hits: 67.46%
# Epoch: 085, Loss: 0.0929, Val Hits: 54.75%, Test Hits: 64.12%
# Epoch: 086, Loss: 0.0930, Val Hits: 50.35%, Test Hits: 59.62%
# Epoch: 087, Loss: 0.0927, Val Hits: 56.86%, Test Hits: 66.59%
# Epoch: 088, Loss: 0.0925, Val Hits: 59.94%, Test Hits: 67.93%
# Epoch: 089, Loss: 0.0924, Val Hits: 59.66%, Test Hits: 67.39%
# Epoch: 090, Loss: 0.0926, Val Hits: 56.87%, Test Hits: 67.66%
# Epoch: 091, Loss: 0.0924, Val Hits: 57.36%, Test Hits: 65.90%
# Epoch: 092, Loss: 0.0921, Val Hits: 56.18%, Test Hits: 64.21%
# Epoch: 093, Loss: 0.0920, Val Hits: 56.92%, Test Hits: 64.98%
# Epoch: 094, Loss: 0.0920, Val Hits: 57.39%, Test Hits: 64.85%
# Epoch: 095, Loss: 0.0916, Val Hits: 57.33%, Test Hits: 66.41%
# Epoch: 096, Loss: 0.0912, Val Hits: 57.80%, Test Hits: 64.19%
# Epoch: 097, Loss: 0.0914, Val Hits: 62.13%, Test Hits: 66.32%
# Epoch: 098, Loss: 0.0909, Val Hits: 58.79%, Test Hits: 67.77%
# Epoch: 099, Loss: 0.0915, Val Hits: 58.57%, Test Hits: 68.45%
# Epoch: 100, Loss: 0.0909, Val Hits: 57.77%, Test Hits: 67.30%
# Epoch: 101, Loss: 0.0910, Val Hits: 59.59%, Test Hits: 71.85%
# Epoch: 102, Loss: 0.0908, Val Hits: 56.83%, Test Hits: 67.51%
# Epoch: 103, Loss: 0.0908, Val Hits: 55.67%, Test Hits: 64.98%
# Epoch: 104, Loss: 0.0908, Val Hits: 58.37%, Test Hits: 67.84%
# Epoch: 105, Loss: 0.0905, Val Hits: 56.79%, Test Hits: 68.38%
# Epoch: 106, Loss: 0.0909, Val Hits: 59.56%, Test Hits: 65.49%
# Epoch: 107, Loss: 0.0903, Val Hits: 58.75%, Test Hits: 63.59%
# Epoch: 108, Loss: 0.0908, Val Hits: 57.91%, Test Hits: 69.75%
# Epoch: 109, Loss: 0.0900, Val Hits: 59.34%, Test Hits: 66.56%
# Epoch: 110, Loss: 0.0909, Val Hits: 57.45%, Test Hits: 66.05%
# Epoch: 111, Loss: 0.0902, Val Hits: 58.97%, Test Hits: 68.93%
# Epoch: 112, Loss: 0.0900, Val Hits: 59.38%, Test Hits: 68.81%
# Epoch: 113, Loss: 0.0896, Val Hits: 56.66%, Test Hits: 68.74%
# Epoch: 114, Loss: 0.0900, Val Hits: 61.01%, Test Hits: 70.04%
# Epoch: 115, Loss: 0.0896, Val Hits: 57.54%, Test Hits: 67.45%
# Epoch: 116, Loss: 0.0892, Val Hits: 57.39%, Test Hits: 67.53%
# Epoch: 117, Loss: 0.0893, Val Hits: 60.09%, Test Hits: 72.01%
# Epoch: 118, Loss: 0.0897, Val Hits: 62.25%, Test Hits: 67.26%
# Epoch: 119, Loss: 0.0893, Val Hits: 59.06%, Test Hits: 67.40%
# Epoch: 120, Loss: 0.0891, Val Hits: 59.67%, Test Hits: 69.39%
# Epoch: 121, Loss: 0.0891, Val Hits: 60.53%, Test Hits: 70.43%
# Epoch: 122, Loss: 0.0893, Val Hits: 59.75%, Test Hits: 71.35%
# Epoch: 123, Loss: 0.0894, Val Hits: 60.30%, Test Hits: 71.63%
# Epoch: 124, Loss: 0.0886, Val Hits: 62.34%, Test Hits: 72.21%
# Epoch: 125, Loss: 0.0893, Val Hits: 59.74%, Test Hits: 70.51%
# Epoch: 126, Loss: 0.0887, Val Hits: 59.40%, Test Hits: 69.55%
# Epoch: 127, Loss: 0.0888, Val Hits: 60.49%, Test Hits: 73.78%
# Epoch: 128, Loss: 0.0888, Val Hits: 59.80%, Test Hits: 70.20%
# Epoch: 129, Loss: 0.0893, Val Hits: 61.73%, Test Hits: 70.99%
# Epoch: 130, Loss: 0.0886, Val Hits: 60.98%, Test Hits: 69.09%
# Epoch: 131, Loss: 0.0883, Val Hits: 60.72%, Test Hits: 70.07%
# Epoch: 132, Loss: 0.0884, Val Hits: 59.46%, Test Hits: 71.49%
# Epoch: 133, Loss: 0.0883, Val Hits: 62.76%, Test Hits: 70.89%
# Epoch: 134, Loss: 0.0876, Val Hits: 61.47%, Test Hits: 70.85%
# Epoch: 135, Loss: 0.0883, Val Hits: 63.08%, Test Hits: 68.76%
# Epoch: 136, Loss: 0.0887, Val Hits: 60.84%, Test Hits: 66.24%
# Epoch: 137, Loss: 0.0880, Val Hits: 62.64%, Test Hits: 73.19%
# Epoch: 138, Loss: 0.0884, Val Hits: 60.46%, Test Hits: 69.81%
# Epoch: 139, Loss: 0.0886, Val Hits: 61.10%, Test Hits: 73.12%
# Epoch: 140, Loss: 0.0882, Val Hits: 61.90%, Test Hits: 69.68%
# Epoch: 141, Loss: 0.0877, Val Hits: 60.63%, Test Hits: 69.98%
# Epoch: 142, Loss: 0.0878, Val Hits: 61.87%, Test Hits: 70.19%
# Epoch: 143, Loss: 0.0877, Val Hits: 61.70%, Test Hits: 71.42%
# Epoch: 144, Loss: 0.0878, Val Hits: 63.96%, Test Hits: 72.77%
# Epoch: 145, Loss: 0.0874, Val Hits: 64.48%, Test Hits: 71.99%
# Epoch: 146, Loss: 0.0876, Val Hits: 62.19%, Test Hits: 69.31%
# Epoch: 147, Loss: 0.0870, Val Hits: 61.05%, Test Hits: 69.77%
# Epoch: 148, Loss: 0.0870, Val Hits: 64.41%, Test Hits: 73.02%
# Epoch: 149, Loss: 0.0876, Val Hits: 61.32%, Test Hits: 73.20%
# Epoch: 150, Loss: 0.0873, Val Hits: 59.85%, Test Hits: 69.34%
# Epoch: 151, Loss: 0.0877, Val Hits: 62.23%, Test Hits: 72.60%
# Epoch: 152, Loss: 0.0876, Val Hits: 61.66%, Test Hits: 70.71%
# Epoch: 153, Loss: 0.0867, Val Hits: 64.08%, Test Hits: 71.78%
# Epoch: 154, Loss: 0.0874, Val Hits: 60.36%, Test Hits: 69.89%
# Epoch: 155, Loss: 0.0865, Val Hits: 64.32%, Test Hits: 70.16%
# Epoch: 156, Loss: 0.0869, Val Hits: 60.80%, Test Hits: 72.00%
# Epoch: 157, Loss: 0.0870, Val Hits: 63.03%, Test Hits: 71.67%
# Epoch: 158, Loss: 0.0869, Val Hits: 61.11%, Test Hits: 67.89%
# Epoch: 159, Loss: 0.0877, Val Hits: 63.64%, Test Hits: 68.84%
# Epoch: 160, Loss: 0.0867, Val Hits: 62.74%, Test Hits: 68.82%
# Epoch: 161, Loss: 0.0869, Val Hits: 61.11%, Test Hits: 67.55%
# Epoch: 162, Loss: 0.0874, Val Hits: 62.83%, Test Hits: 69.77%
# Epoch: 163, Loss: 0.0871, Val Hits: 61.04%, Test Hits: 67.94%
# Epoch: 164, Loss: 0.0868, Val Hits: 61.46%, Test Hits: 63.66%
# Epoch: 165, Loss: 0.0871, Val Hits: 62.59%, Test Hits: 69.55%
# Epoch: 166, Loss: 0.0864, Val Hits: 63.05%, Test Hits: 70.01%
# Epoch: 167, Loss: 0.0870, Val Hits: 61.92%, Test Hits: 68.78%
# Epoch: 168, Loss: 0.0870, Val Hits: 58.59%, Test Hits: 72.33%
# Epoch: 169, Loss: 0.0868, Val Hits: 63.12%, Test Hits: 71.73%
# Epoch: 170, Loss: 0.0870, Val Hits: 63.51%, Test Hits: 74.35%
# Epoch: 171, Loss: 0.0865, Val Hits: 62.59%, Test Hits: 73.33%
# Epoch: 172, Loss: 0.0866, Val Hits: 62.84%, Test Hits: 73.12%
# Epoch: 173, Loss: 0.0863, Val Hits: 62.81%, Test Hits: 71.02%
# Epoch: 174, Loss: 0.0859, Val Hits: 62.38%, Test Hits: 72.03%
# Epoch: 175, Loss: 0.0869, Val Hits: 63.34%, Test Hits: 74.75%
# Epoch: 176, Loss: 0.0864, Val Hits: 62.82%, Test Hits: 72.12%
# Epoch: 177, Loss: 0.0861, Val Hits: 61.02%, Test Hits: 73.08%
# Epoch: 178, Loss: 0.0870, Val Hits: 62.14%, Test Hits: 71.42%
# Epoch: 179, Loss: 0.0867, Val Hits: 62.46%, Test Hits: 71.70%
# Epoch: 180, Loss: 0.0863, Val Hits: 62.14%, Test Hits: 69.18%
# Epoch: 181, Loss: 0.0860, Val Hits: 61.54%, Test Hits: 68.21%
# Epoch: 182, Loss: 0.0858, Val Hits: 62.61%, Test Hits: 72.44%
# Epoch: 183, Loss: 0.0862, Val Hits: 62.11%, Test Hits: 73.59%
# Epoch: 184, Loss: 0.0862, Val Hits: 62.58%, Test Hits: 72.75%
# Epoch: 185, Loss: 0.0859, Val Hits: 62.10%, Test Hits: 70.67%
# Epoch: 186, Loss: 0.0861, Val Hits: 62.75%, Test Hits: 76.64%
# Epoch: 187, Loss: 0.0854, Val Hits: 64.00%, Test Hits: 74.53%
# Epoch: 188, Loss: 0.0853, Val Hits: 63.00%, Test Hits: 74.61%
# Epoch: 189, Loss: 0.0852, Val Hits: 63.28%, Test Hits: 74.72%
# Epoch: 190, Loss: 0.0859, Val Hits: 60.54%, Test Hits: 72.69%
# Epoch: 191, Loss: 0.0857, Val Hits: 61.64%, Test Hits: 73.20%
# Epoch: 192, Loss: 0.0856, Val Hits: 60.89%, Test Hits: 74.01%
# Epoch: 193, Loss: 0.0861, Val Hits: 62.53%, Test Hits: 73.56%
# Epoch: 194, Loss: 0.0850, Val Hits: 58.81%, Test Hits: 66.46%
# Epoch: 195, Loss: 0.0858, Val Hits: 62.39%, Test Hits: 72.46%
# Epoch: 196, Loss: 0.0858, Val Hits: 62.21%, Test Hits: 74.42%
# Epoch: 197, Loss: 0.0856, Val Hits: 62.91%, Test Hits: 75.48%
# Epoch: 198, Loss: 0.0856, Val Hits: 63.51%, Test Hits: 72.63%
# Epoch: 199, Loss: 0.0856, Val Hits: 62.91%, Test Hits: 71.75%
# Epoch: 200, Loss: 0.0855, Val Hits: 63.67%, Test Hits: 77.20%
# Epoch: 201, Loss: 0.0849, Val Hits: 65.32%, Test Hits: 76.78%
# Epoch: 202, Loss: 0.0851, Val Hits: 65.08%, Test Hits: 73.02%
# Epoch: 203, Loss: 0.0849, Val Hits: 61.95%, Test Hits: 70.85%
# Epoch: 204, Loss: 0.0860, Val Hits: 63.90%, Test Hits: 74.27%
# Epoch: 205, Loss: 0.0854, Val Hits: 63.18%, Test Hits: 72.01%
# Epoch: 206, Loss: 0.0854, Val Hits: 60.05%, Test Hits: 73.90%
# Epoch: 207, Loss: 0.0852, Val Hits: 61.41%, Test Hits: 73.40%
# Epoch: 208, Loss: 0.0851, Val Hits: 63.53%, Test Hits: 71.82%
# Epoch: 209, Loss: 0.0852, Val Hits: 62.19%, Test Hits: 71.53%
# Epoch: 210, Loss: 0.0854, Val Hits: 61.65%, Test Hits: 72.91%
# Epoch: 211, Loss: 0.0850, Val Hits: 63.88%, Test Hits: 75.03%
# Epoch: 212, Loss: 0.0850, Val Hits: 61.89%, Test Hits: 73.06%
# Epoch: 213, Loss: 0.0846, Val Hits: 63.70%, Test Hits: 72.56%
# Epoch: 214, Loss: 0.0847, Val Hits: 63.77%, Test Hits: 76.14%
# Epoch: 215, Loss: 0.0848, Val Hits: 62.00%, Test Hits: 72.70%
# Epoch: 216, Loss: 0.0852, Val Hits: 62.61%, Test Hits: 73.80%
# Epoch: 217, Loss: 0.0850, Val Hits: 63.27%, Test Hits: 73.91%
# Epoch: 218, Loss: 0.0853, Val Hits: 63.88%, Test Hits: 73.91%
# Epoch: 219, Loss: 0.0845, Val Hits: 63.81%, Test Hits: 75.76%
# Epoch: 220, Loss: 0.0851, Val Hits: 65.11%, Test Hits: 77.75%
# Epoch: 221, Loss: 0.0849, Val Hits: 61.97%, Test Hits: 73.67%
# Epoch: 222, Loss: 0.0854, Val Hits: 62.82%, Test Hits: 75.87%
# Epoch: 223, Loss: 0.0842, Val Hits: 63.14%, Test Hits: 74.35%
# Epoch: 224, Loss: 0.0847, Val Hits: 61.75%, Test Hits: 75.07%
# Epoch: 225, Loss: 0.0844, Val Hits: 63.99%, Test Hits: 72.86%
# Epoch: 226, Loss: 0.0842, Val Hits: 64.78%, Test Hits: 75.81%
# Epoch: 227, Loss: 0.0845, Val Hits: 64.89%, Test Hits: 75.97%
# Epoch: 228, Loss: 0.0848, Val Hits: 63.87%, Test Hits: 74.60%
# Epoch: 229, Loss: 0.0849, Val Hits: 63.79%, Test Hits: 77.44%
# Epoch: 230, Loss: 0.0842, Val Hits: 63.94%, Test Hits: 73.27%
# Epoch: 231, Loss: 0.0851, Val Hits: 63.95%, Test Hits: 77.69%
# Epoch: 232, Loss: 0.0848, Val Hits: 64.85%, Test Hits: 77.37%
# Epoch: 233, Loss: 0.0842, Val Hits: 63.84%, Test Hits: 71.92%
# Epoch: 234, Loss: 0.0845, Val Hits: 62.57%, Test Hits: 76.67%
# Epoch: 235, Loss: 0.0852, Val Hits: 64.16%, Test Hits: 73.64%
# Epoch: 236, Loss: 0.0846, Val Hits: 65.32%, Test Hits: 77.85%
# Epoch: 237, Loss: 0.0849, Val Hits: 62.76%, Test Hits: 73.19%
# Epoch: 238, Loss: 0.0847, Val Hits: 61.03%, Test Hits: 77.16%
# Epoch: 239, Loss: 0.0841, Val Hits: 64.06%, Test Hits: 75.88%
# Epoch: 240, Loss: 0.0847, Val Hits: 61.79%, Test Hits: 74.93%
# Epoch: 241, Loss: 0.0843, Val Hits: 64.50%, Test Hits: 77.16%
# Epoch: 242, Loss: 0.0841, Val Hits: 62.71%, Test Hits: 75.24%
# Epoch: 243, Loss: 0.0845, Val Hits: 64.40%, Test Hits: 76.81%
# Epoch: 244, Loss: 0.0840, Val Hits: 63.13%, Test Hits: 77.18%
# Epoch: 245, Loss: 0.0845, Val Hits: 63.48%, Test Hits: 76.60%
# Epoch: 246, Loss: 0.0839, Val Hits: 63.44%, Test Hits: 75.04%
# Epoch: 247, Loss: 0.0833, Val Hits: 63.23%, Test Hits: 76.81%
# Epoch: 248, Loss: 0.0846, Val Hits: 65.21%, Test Hits: 78.34%
# Epoch: 249, Loss: 0.0839, Val Hits: 62.34%, Test Hits: 76.78%
# Epoch: 250, Loss: 0.0840, Val Hits: 64.46%, Test Hits: 79.13%
# Epoch: 251, Loss: 0.0845, Val Hits: 61.91%, Test Hits: 74.59%
# Epoch: 252, Loss: 0.0838, Val Hits: 64.51%, Test Hits: 78.90%
# Epoch: 253, Loss: 0.0837, Val Hits: 62.85%, Test Hits: 77.74%
# Epoch: 254, Loss: 0.0842, Val Hits: 64.85%, Test Hits: 78.63%
# Epoch: 255, Loss: 0.0836, Val Hits: 63.74%, Test Hits: 77.35%
# Epoch: 256, Loss: 0.0837, Val Hits: 63.98%, Test Hits: 78.37%
# Epoch: 257, Loss: 0.0840, Val Hits: 64.22%, Test Hits: 74.56%
# Epoch: 258, Loss: 0.0833, Val Hits: 62.81%, Test Hits: 77.52%
# Epoch: 259, Loss: 0.0845, Val Hits: 64.30%, Test Hits: 74.96%
# Epoch: 260, Loss: 0.0840, Val Hits: 64.03%, Test Hits: 76.49%
# Epoch: 261, Loss: 0.0840, Val Hits: 65.43%, Test Hits: 76.11%
# Epoch: 262, Loss: 0.0835, Val Hits: 62.86%, Test Hits: 73.24%
# Epoch: 263, Loss: 0.0840, Val Hits: 63.63%, Test Hits: 75.89%
# Epoch: 264, Loss: 0.0838, Val Hits: 64.80%, Test Hits: 73.68%
# Epoch: 265, Loss: 0.0833, Val Hits: 62.77%, Test Hits: 74.82%
# Epoch: 266, Loss: 0.0836, Val Hits: 62.93%, Test Hits: 72.05%
# Epoch: 267, Loss: 0.0840, Val Hits: 65.97%, Test Hits: 78.23%
# Epoch: 268, Loss: 0.0837, Val Hits: 62.40%, Test Hits: 77.06%
# Epoch: 269, Loss: 0.0832, Val Hits: 63.06%, Test Hits: 79.13%
# Epoch: 270, Loss: 0.0838, Val Hits: 63.83%, Test Hits: 79.92%
# Epoch: 271, Loss: 0.0837, Val Hits: 64.44%, Test Hits: 78.54%
# Epoch: 272, Loss: 0.0835, Val Hits: 63.46%, Test Hits: 79.20%
# Epoch: 273, Loss: 0.0835, Val Hits: 63.77%, Test Hits: 73.81%
# Epoch: 274, Loss: 0.0835, Val Hits: 64.20%, Test Hits: 79.80%
# Epoch: 275, Loss: 0.0834, Val Hits: 63.07%, Test Hits: 75.94%
# Epoch: 276, Loss: 0.0837, Val Hits: 62.59%, Test Hits: 71.18%
# Epoch: 277, Loss: 0.0835, Val Hits: 63.56%, Test Hits: 76.71%
# Epoch: 278, Loss: 0.0833, Val Hits: 62.80%, Test Hits: 75.89%
# Epoch: 279, Loss: 0.0833, Val Hits: 64.22%, Test Hits: 76.43%
# Epoch: 280, Loss: 0.0837, Val Hits: 62.84%, Test Hits: 70.48%
# Epoch: 281, Loss: 0.0831, Val Hits: 65.08%, Test Hits: 77.15%
# Epoch: 282, Loss: 0.0843, Val Hits: 64.17%, Test Hits: 79.41%
# Epoch: 283, Loss: 0.0831, Val Hits: 64.26%, Test Hits: 79.94%
# Epoch: 284, Loss: 0.0835, Val Hits: 64.91%, Test Hits: 77.92%
# Epoch: 285, Loss: 0.0831, Val Hits: 64.45%, Test Hits: 78.20%
# Epoch: 286, Loss: 0.0831, Val Hits: 63.46%, Test Hits: 78.19%
# Epoch: 287, Loss: 0.0829, Val Hits: 64.79%, Test Hits: 79.64%
# Epoch: 288, Loss: 0.0833, Val Hits: 64.95%, Test Hits: 79.32%
# Epoch: 289, Loss: 0.0835, Val Hits: 63.92%, Test Hits: 79.45%
# Epoch: 290, Loss: 0.0834, Val Hits: 62.96%, Test Hits: 79.40%
# Epoch: 291, Loss: 0.0831, Val Hits: 64.85%, Test Hits: 78.49%
# Epoch: 292, Loss: 0.0832, Val Hits: 63.84%, Test Hits: 77.14%
# Epoch: 293, Loss: 0.0828, Val Hits: 62.95%, Test Hits: 76.88%
# Epoch: 294, Loss: 0.0832, Val Hits: 63.87%, Test Hits: 76.21%
# Epoch: 295, Loss: 0.0825, Val Hits: 64.39%, Test Hits: 78.56%
# Epoch: 296, Loss: 0.0836, Val Hits: 66.91%, Test Hits: 79.70%
# Epoch: 297, Loss: 0.0833, Val Hits: 66.28%, Test Hits: 78.64%
# Epoch: 298, Loss: 0.0833, Val Hits: 64.09%, Test Hits: 78.25%
# Epoch: 299, Loss: 0.0832, Val Hits: 66.46%, Test Hits: 76.08%
# Epoch: 300, Loss: 0.0828, Val Hits: 61.80%, Test Hits: 71.50%
# Epoch: 301, Loss: 0.0827, Val Hits: 65.64%, Test Hits: 78.56%
# Epoch: 302, Loss: 0.0832, Val Hits: 63.49%, Test Hits: 78.88%
# Epoch: 303, Loss: 0.0834, Val Hits: 67.41%, Test Hits: 79.12%
# Epoch: 304, Loss: 0.0830, Val Hits: 66.09%, Test Hits: 78.82%
# Epoch: 305, Loss: 0.0828, Val Hits: 65.54%, Test Hits: 77.78%
# Epoch: 306, Loss: 0.0831, Val Hits: 65.75%, Test Hits: 79.27%
# Epoch: 307, Loss: 0.0830, Val Hits: 65.27%, Test Hits: 77.13%
# Epoch: 308, Loss: 0.0833, Val Hits: 64.64%, Test Hits: 78.66%
# Epoch: 309, Loss: 0.0832, Val Hits: 65.75%, Test Hits: 80.03%
# Epoch: 310, Loss: 0.0829, Val Hits: 66.55%, Test Hits: 78.75%
# Epoch: 311, Loss: 0.0827, Val Hits: 63.72%, Test Hits: 78.36%
# Epoch: 312, Loss: 0.0836, Val Hits: 65.45%, Test Hits: 76.14%
# Epoch: 313, Loss: 0.0829, Val Hits: 38.78%, Test Hits: 69.55%
# Epoch: 314, Loss: 0.0827, Val Hits: 66.02%, Test Hits: 79.69%
# Epoch: 315, Loss: 0.0828, Val Hits: 65.97%, Test Hits: 79.55%
# Epoch: 316, Loss: 0.0825, Val Hits: 65.17%, Test Hits: 78.84%
# Epoch: 317, Loss: 0.0825, Val Hits: 65.61%, Test Hits: 79.60%
# Epoch: 318, Loss: 0.0830, Val Hits: 66.05%, Test Hits: 79.72%
# Epoch: 319, Loss: 0.0830, Val Hits: 61.95%, Test Hits: 76.36%
# Epoch: 320, Loss: 0.0828, Val Hits: 65.68%, Test Hits: 80.36%
# Epoch: 321, Loss: 0.0821, Val Hits: 63.86%, Test Hits: 76.46%
# Epoch: 322, Loss: 0.0822, Val Hits: 65.99%, Test Hits: 76.39%
# Epoch: 323, Loss: 0.0823, Val Hits: 65.45%, Test Hits: 77.78%
# Epoch: 324, Loss: 0.0824, Val Hits: 65.86%, Test Hits: 77.89%
# Epoch: 325, Loss: 0.0824, Val Hits: 66.22%, Test Hits: 80.79%
# Epoch: 326, Loss: 0.0823, Val Hits: 64.13%, Test Hits: 75.02%
# Epoch: 327, Loss: 0.0823, Val Hits: 66.64%, Test Hits: 80.96%
# Epoch: 328, Loss: 0.0827, Val Hits: 61.58%, Test Hits: 75.52%
# Epoch: 329, Loss: 0.0828, Val Hits: 65.70%, Test Hits: 79.30%
# Epoch: 330, Loss: 0.0819, Val Hits: 65.12%, Test Hits: 77.81%
# Epoch: 331, Loss: 0.0829, Val Hits: 65.15%, Test Hits: 78.59%
# Epoch: 332, Loss: 0.0829, Val Hits: 65.03%, Test Hits: 77.01%
# Epoch: 333, Loss: 0.0823, Val Hits: 62.31%, Test Hits: 78.37%
# Epoch: 334, Loss: 0.0825, Val Hits: 64.89%, Test Hits: 76.88%
# Epoch: 335, Loss: 0.0828, Val Hits: 65.79%, Test Hits: 77.60%
# Epoch: 336, Loss: 0.0822, Val Hits: 63.51%, Test Hits: 77.50%
# Epoch: 337, Loss: 0.0822, Val Hits: 65.97%, Test Hits: 75.82%
# Epoch: 338, Loss: 0.0826, Val Hits: 66.38%, Test Hits: 81.63%
# Epoch: 339, Loss: 0.0824, Val Hits: 67.42%, Test Hits: 80.32%
# Epoch: 340, Loss: 0.0822, Val Hits: 66.56%, Test Hits: 78.46%
# Epoch: 341, Loss: 0.0823, Val Hits: 67.12%, Test Hits: 76.93%
# Epoch: 342, Loss: 0.0824, Val Hits: 65.27%, Test Hits: 80.32%
# Epoch: 343, Loss: 0.0823, Val Hits: 64.65%, Test Hits: 76.06%
# Epoch: 344, Loss: 0.0823, Val Hits: 66.83%, Test Hits: 79.56%
# Epoch: 345, Loss: 0.0823, Val Hits: 67.51%, Test Hits: 78.92%
# Epoch: 346, Loss: 0.0825, Val Hits: 66.18%, Test Hits: 79.14%
# Epoch: 347, Loss: 0.0825, Val Hits: 66.08%, Test Hits: 79.35%
# Epoch: 348, Loss: 0.0824, Val Hits: 64.10%, Test Hits: 75.97%
# Epoch: 349, Loss: 0.0824, Val Hits: 65.57%, Test Hits: 76.37%
# Epoch: 350, Loss: 0.0819, Val Hits: 67.00%, Test Hits: 76.77%
# Epoch: 351, Loss: 0.0823, Val Hits: 63.94%, Test Hits: 79.33%
# Epoch: 352, Loss: 0.0818, Val Hits: 64.61%, Test Hits: 77.31%
# Epoch: 353, Loss: 0.0821, Val Hits: 66.02%, Test Hits: 77.31%
# Epoch: 354, Loss: 0.0826, Val Hits: 65.22%, Test Hits: 78.17%
# Epoch: 355, Loss: 0.0821, Val Hits: 65.31%, Test Hits: 75.79%
# Epoch: 356, Loss: 0.0825, Val Hits: 60.23%, Test Hits: 72.98%
# Epoch: 357, Loss: 0.0819, Val Hits: 64.58%, Test Hits: 76.25%
# Epoch: 358, Loss: 0.0823, Val Hits: 64.66%, Test Hits: 79.04%
# Epoch: 359, Loss: 0.0819, Val Hits: 64.63%, Test Hits: 77.90%
# Epoch: 360, Loss: 0.0819, Val Hits: 66.25%, Test Hits: 77.59%
# Epoch: 361, Loss: 0.0822, Val Hits: 65.58%, Test Hits: 79.06%
# Epoch: 362, Loss: 0.0823, Val Hits: 66.08%, Test Hits: 77.71%
# Epoch: 363, Loss: 0.0819, Val Hits: 67.05%, Test Hits: 78.00%
# Epoch: 364, Loss: 0.0820, Val Hits: 65.61%, Test Hits: 78.20%
# Epoch: 365, Loss: 0.0827, Val Hits: 65.65%, Test Hits: 77.92%
# Epoch: 366, Loss: 0.0820, Val Hits: 61.79%, Test Hits: 75.52%
# Epoch: 367, Loss: 0.0819, Val Hits: 61.18%, Test Hits: 71.73%
# Epoch: 368, Loss: 0.0818, Val Hits: 65.62%, Test Hits: 76.47%
# Epoch: 369, Loss: 0.0819, Val Hits: 66.49%, Test Hits: 77.08%
# Epoch: 370, Loss: 0.0817, Val Hits: 65.91%, Test Hits: 76.36%
# Epoch: 371, Loss: 0.0818, Val Hits: 65.49%, Test Hits: 74.98%
# Epoch: 372, Loss: 0.0815, Val Hits: 65.03%, Test Hits: 77.42%
# Epoch: 373, Loss: 0.0819, Val Hits: 64.35%, Test Hits: 78.95%
# ...
# Epoch: 146, Loss: 0.0869, Val Hits: 59.07%, Test Hits: 64.33%
# Epoch: 147, Loss: 0.0868, Val Hits: 61.97%, Test Hits: 69.55%
# Epoch: 148, Loss: 0.0877, Val Hits: 59.87%, Test Hits: 64.09%
# Epoch: 149, Loss: 0.0875, Val Hits: 58.02%, Test Hits: 66.81%
# Epoch: 150, Loss: 0.0871, Val Hits: 59.25%, Test Hits: 67.09%
# Epoch: 151, Loss: 0.0874, Val Hits: 59.17%, Test Hits: 64.97%
# Epoch: 152, Loss: 0.0867, Val Hits: 59.76%, Test Hits: 64.34%
# Epoch: 153, Loss: 0.0865, Val Hits: 56.86%, Test Hits: 62.94%
# Epoch: 154, Loss: 0.0867, Val Hits: 59.26%, Test Hits: 61.41%
# Epoch: 155, Loss: 0.0866, Val Hits: 58.47%, Test Hits: 69.33%
# Epoch: 156, Loss: 0.0870, Val Hits: 57.87%, Test Hits: 66.32%
# Epoch: 157, Loss: 0.0863, Val Hits: 58.92%, Test Hits: 64.86%
# Epoch: 158, Loss: 0.0863, Val Hits: 59.96%, Test Hits: 62.11%
# Epoch: 159, Loss: 0.0867, Val Hits: 59.63%, Test Hits: 65.44%
# Epoch: 160, Loss: 0.0870, Val Hits: 58.33%, Test Hits: 66.12%
# Epoch: 161, Loss: 0.0863, Val Hits: 57.59%, Test Hits: 62.54%
# Epoch: 162, Loss: 0.0866, Val Hits: 59.35%, Test Hits: 65.87%
# Epoch: 163, Loss: 0.0865, Val Hits: 50.96%, Test Hits: 56.22%
# Epoch: 164, Loss: 0.0863, Val Hits: 55.40%, Test Hits: 60.67%
# Epoch: 165, Loss: 0.0864, Val Hits: 58.49%, Test Hits: 65.48%
# Epoch: 166, Loss: 0.0865, Val Hits: 59.82%, Test Hits: 67.56%
# Epoch: 167, Loss: 0.0861, Val Hits: 59.54%, Test Hits: 66.43%
# Epoch: 168, Loss: 0.0859, Val Hits: 58.64%, Test Hits: 68.69%
# Epoch: 169, Loss: 0.0861, Val Hits: 59.58%, Test Hits: 65.15%
# Epoch: 170, Loss: 0.0860, Val Hits: 56.45%, Test Hits: 64.26%
# Epoch: 171, Loss: 0.0863, Val Hits: 56.06%, Test Hits: 65.09%
# Epoch: 172, Loss: 0.0862, Val Hits: 61.24%, Test Hits: 69.62%
# Epoch: 173, Loss: 0.0859, Val Hits: 59.58%, Test Hits: 65.67%
# Epoch: 174, Loss: 0.0859, Val Hits: 60.78%, Test Hits: 64.52%
# Epoch: 175, Loss: 0.0860, Val Hits: 62.72%, Test Hits: 68.04%
# Epoch: 176, Loss: 0.0861, Val Hits: 60.50%, Test Hits: 65.00%
# Epoch: 177, Loss: 0.0861, Val Hits: 57.62%, Test Hits: 63.26%
# Epoch: 178, Loss: 0.0853, Val Hits: 59.59%, Test Hits: 70.43%
# Epoch: 179, Loss: 0.0857, Val Hits: 62.51%, Test Hits: 69.92%
# Epoch: 180, Loss: 0.0857, Val Hits: 61.45%, Test Hits: 69.33%
# Epoch: 181, Loss: 0.0859, Val Hits: 60.39%, Test Hits: 68.03%
# Epoch: 182, Loss: 0.0857, Val Hits: 62.17%, Test Hits: 68.63%
# Epoch: 183, Loss: 0.0854, Val Hits: 62.55%, Test Hits: 68.47%
# Epoch: 184, Loss: 0.0857, Val Hits: 59.17%, Test Hits: 69.94%
# Epoch: 185, Loss: 0.0852, Val Hits: 56.86%, Test Hits: 62.57%
# Epoch: 186, Loss: 0.0859, Val Hits: 58.39%, Test Hits: 67.93%
# Epoch: 187, Loss: 0.0851, Val Hits: 62.45%, Test Hits: 67.14%
# Epoch: 188, Loss: 0.0851, Val Hits: 61.39%, Test Hits: 65.79%
# Epoch: 189, Loss: 0.0853, Val Hits: 63.74%, Test Hits: 66.42%
# Epoch: 190, Loss: 0.0853, Val Hits: 62.17%, Test Hits: 66.50%
# Epoch: 191, Loss: 0.0853, Val Hits: 62.98%, Test Hits: 70.69%
# Epoch: 192, Loss: 0.0858, Val Hits: 62.77%, Test Hits: 69.86%
# Epoch: 193, Loss: 0.0848, Val Hits: 60.92%, Test Hits: 68.77%
# Epoch: 194, Loss: 0.0853, Val Hits: 61.87%, Test Hits: 71.13%
# Epoch: 195, Loss: 0.0855, Val Hits: 61.07%, Test Hits: 69.69%
# Epoch: 196, Loss: 0.0858, Val Hits: 59.53%, Test Hits: 68.00%
# Epoch: 197, Loss: 0.0849, Val Hits: 61.62%, Test Hits: 70.98%
# Epoch: 198, Loss: 0.0850, Val Hits: 61.40%, Test Hits: 73.11%
# Epoch: 199, Loss: 0.0853, Val Hits: 61.15%, Test Hits: 69.83%
# Epoch: 200, Loss: 0.0848, Val Hits: 61.17%, Test Hits: 66.27%
# Epoch: 201, Loss: 0.0845, Val Hits: 61.13%, Test Hits: 66.25%
# Epoch: 202, Loss: 0.0847, Val Hits: 60.56%, Test Hits: 67.88%
# Epoch: 203, Loss: 0.0847, Val Hits: 59.16%, Test Hits: 68.74%
# Epoch: 204, Loss: 0.0854, Val Hits: 60.15%, Test Hits: 67.20%
# Epoch: 205, Loss: 0.0846, Val Hits: 60.61%, Test Hits: 69.24%
# Epoch: 206, Loss: 0.0846, Val Hits: 62.47%, Test Hits: 69.52%
# Epoch: 207, Loss: 0.0848, Val Hits: 61.19%, Test Hits: 68.59%
# Epoch: 208, Loss: 0.0849, Val Hits: 60.86%, Test Hits: 65.09%
# Epoch: 209, Loss: 0.0849, Val Hits: 63.49%, Test Hits: 71.75%
# Epoch: 210, Loss: 0.0847, Val Hits: 62.63%, Test Hits: 67.61%
# Epoch: 211, Loss: 0.0849, Val Hits: 62.06%, Test Hits: 68.00%
# Epoch: 212, Loss: 0.0850, Val Hits: 61.97%, Test Hits: 71.75%
# Epoch: 213, Loss: 0.0850, Val Hits: 62.57%, Test Hits: 69.55%
# Epoch: 214, Loss: 0.0844, Val Hits: 63.19%, Test Hits: 70.46%
# Epoch: 215, Loss: 0.0852, Val Hits: 64.34%, Test Hits: 68.95%
# Epoch: 216, Loss: 0.0843, Val Hits: 62.95%, Test Hits: 68.65%
# Epoch: 217, Loss: 0.0847, Val Hits: 63.95%, Test Hits: 68.29%
# Epoch: 218, Loss: 0.0843, Val Hits: 61.95%, Test Hits: 66.86%
# Epoch: 219, Loss: 0.0843, Val Hits: 63.14%, Test Hits: 66.91%
# Epoch: 220, Loss: 0.0842, Val Hits: 65.17%, Test Hits: 71.62%
# Epoch: 221, Loss: 0.0842, Val Hits: 59.52%, Test Hits: 61.38%
# Epoch: 222, Loss: 0.0840, Val Hits: 60.27%, Test Hits: 66.43%
# Epoch: 223, Loss: 0.0839, Val Hits: 63.60%, Test Hits: 69.04%
# Epoch: 224, Loss: 0.0845, Val Hits: 63.66%, Test Hits: 70.27%
# Epoch: 225, Loss: 0.0841, Val Hits: 63.37%, Test Hits: 72.83%
# Epoch: 226, Loss: 0.0844, Val Hits: 63.23%, Test Hits: 66.45%
# Epoch: 227, Loss: 0.0842, Val Hits: 63.99%, Test Hits: 68.76%
# Epoch: 228, Loss: 0.0838, Val Hits: 63.44%, Test Hits: 67.55%
# Epoch: 229, Loss: 0.0843, Val Hits: 63.75%, Test Hits: 66.47%
# Epoch: 230, Loss: 0.0836, Val Hits: 62.27%, Test Hits: 68.17%
# Epoch: 231, Loss: 0.0841, Val Hits: 58.12%, Test Hits: 65.88%
# Epoch: 232, Loss: 0.0841, Val Hits: 61.28%, Test Hits: 70.31%
# Epoch: 233, Loss: 0.0839, Val Hits: 62.19%, Test Hits: 71.66%
# Epoch: 234, Loss: 0.0841, Val Hits: 62.83%, Test Hits: 72.84%
# Epoch: 235, Loss: 0.0837, Val Hits: 58.48%, Test Hits: 66.88%
# Epoch: 236, Loss: 0.0838, Val Hits: 61.84%, Test Hits: 74.08%
# Epoch: 237, Loss: 0.0838, Val Hits: 55.53%, Test Hits: 61.84%
# Epoch: 238, Loss: 0.0840, Val Hits: 64.24%, Test Hits: 71.06%
# Epoch: 239, Loss: 0.0836, Val Hits: 61.30%, Test Hits: 72.59%
# Epoch: 240, Loss: 0.0837, Val Hits: 64.34%, Test Hits: 69.11%
# Epoch: 241, Loss: 0.0840, Val Hits: 64.00%, Test Hits: 75.38%
# Epoch: 242, Loss: 0.0840, Val Hits: 63.59%, Test Hits: 71.89%
# Epoch: 243, Loss: 0.0839, Val Hits: 61.71%, Test Hits: 71.81%
# Epoch: 244, Loss: 0.0837, Val Hits: 60.67%, Test Hits: 70.31%
# Epoch: 245, Loss: 0.0842, Val Hits: 63.12%, Test Hits: 72.94%
# Epoch: 246, Loss: 0.0838, Val Hits: 61.18%, Test Hits: 69.01%
# Epoch: 247, Loss: 0.0837, Val Hits: 64.95%, Test Hits: 71.81%
# Epoch: 248, Loss: 0.0840, Val Hits: 61.94%, Test Hits: 72.71%
# Epoch: 249, Loss: 0.0828, Val Hits: 61.67%, Test Hits: 67.97%
# Epoch: 250, Loss: 0.0832, Val Hits: 60.11%, Test Hits: 68.87%
# Epoch: 251, Loss: 0.0835, Val Hits: 59.89%, Test Hits: 68.81%
# Epoch: 252, Loss: 0.0836, Val Hits: 62.69%, Test Hits: 69.66%
# Epoch: 253, Loss: 0.0841, Val Hits: 63.54%, Test Hits: 72.77%
# Epoch: 254, Loss: 0.0839, Val Hits: 61.95%, Test Hits: 73.59%
# Epoch: 255, Loss: 0.0835, Val Hits: 57.65%, Test Hits: 66.64%
# Epoch: 256, Loss: 0.0837, Val Hits: 62.95%, Test Hits: 73.76%
# Epoch: 257, Loss: 0.0833, Val Hits: 64.51%, Test Hits: 72.12%
# Epoch: 258, Loss: 0.0836, Val Hits: 58.86%, Test Hits: 68.84%
# Epoch: 259, Loss: 0.0832, Val Hits: 63.35%, Test Hits: 74.71%
# Epoch: 260, Loss: 0.0833, Val Hits: 60.37%, Test Hits: 71.91%
# Epoch: 261, Loss: 0.0829, Val Hits: 62.77%, Test Hits: 65.97%
# Epoch: 262, Loss: 0.0834, Val Hits: 61.99%, Test Hits: 70.08%
# Epoch: 263, Loss: 0.0839, Val Hits: 61.13%, Test Hits: 71.07%
# Epoch: 264, Loss: 0.0829, Val Hits: 61.89%, Test Hits: 73.76%
# Epoch: 265, Loss: 0.0834, Val Hits: 63.09%, Test Hits: 70.59%
# Epoch: 266, Loss: 0.0831, Val Hits: 64.67%, Test Hits: 73.15%
# Epoch: 267, Loss: 0.0830, Val Hits: 62.86%, Test Hits: 69.58%
# Epoch: 268, Loss: 0.0835, Val Hits: 64.41%, Test Hits: 69.02%
# Epoch: 269, Loss: 0.0831, Val Hits: 62.87%, Test Hits: 72.10%
# Epoch: 270, Loss: 0.0829, Val Hits: 64.56%, Test Hits: 71.85%
# Epoch: 271, Loss: 0.0829, Val Hits: 63.78%, Test Hits: 70.16%
# Epoch: 272, Loss: 0.0826, Val Hits: 61.65%, Test Hits: 71.17%
# Epoch: 273, Loss: 0.0829, Val Hits: 62.10%, Test Hits: 74.62%
# Epoch: 274, Loss: 0.0831, Val Hits: 62.79%, Test Hits: 67.57%
# Epoch: 275, Loss: 0.0831, Val Hits: 62.70%, Test Hits: 70.57%
# Epoch: 276, Loss: 0.0825, Val Hits: 62.86%, Test Hits: 71.47%
# Epoch: 277, Loss: 0.0829, Val Hits: 64.14%, Test Hits: 74.16%
# Epoch: 278, Loss: 0.0829, Val Hits: 64.07%, Test Hits: 70.91%
# Epoch: 279, Loss: 0.0833, Val Hits: 64.01%, Test Hits: 72.56%
# Epoch: 280, Loss: 0.0827, Val Hits: 63.77%, Test Hits: 72.48%
# Epoch: 281, Loss: 0.0827, Val Hits: 62.59%, Test Hits: 73.86%
# Epoch: 282, Loss: 0.0827, Val Hits: 62.07%, Test Hits: 71.36%
# Epoch: 283, Loss: 0.0828, Val Hits: 62.83%, Test Hits: 74.85%
# Epoch: 284, Loss: 0.0830, Val Hits: 65.00%, Test Hits: 74.09%
# Epoch: 285, Loss: 0.0828, Val Hits: 64.30%, Test Hits: 74.99%
# Epoch: 286, Loss: 0.0825, Val Hits: 59.84%, Test Hits: 67.78%
# Epoch: 287, Loss: 0.0828, Val Hits: 65.38%, Test Hits: 72.60%
# Epoch: 288, Loss: 0.0831, Val Hits: 64.68%, Test Hits: 70.56%
# Epoch: 289, Loss: 0.0827, Val Hits: 64.26%, Test Hits: 71.89%
# Epoch: 290, Loss: 0.0831, Val Hits: 62.85%, Test Hits: 72.02%
# Epoch: 291, Loss: 0.0827, Val Hits: 63.41%, Test Hits: 68.11%
# Epoch: 292, Loss: 0.0823, Val Hits: 65.11%, Test Hits: 70.45%
# Epoch: 293, Loss: 0.0828, Val Hits: 63.39%, Test Hits: 71.50%
# Epoch: 294, Loss: 0.0828, Val Hits: 61.55%, Test Hits: 71.49%
# Epoch: 295, Loss: 0.0829, Val Hits: 63.92%, Test Hits: 73.02%
# Epoch: 296, Loss: 0.0824, Val Hits: 65.14%, Test Hits: 71.91%
# Epoch: 297, Loss: 0.0818, Val Hits: 64.54%, Test Hits: 71.68%
# Epoch: 298, Loss: 0.0823, Val Hits: 64.31%, Test Hits: 71.60%
# Epoch: 299, Loss: 0.0831, Val Hits: 64.34%, Test Hits: 73.45%
# Epoch: 300, Loss: 0.0829, Val Hits: 63.43%, Test Hits: 74.90%
# Epoch: 301, Loss: 0.0827, Val Hits: 63.95%, Test Hits: 72.92%
# Epoch: 302, Loss: 0.0827, Val Hits: 62.61%, Test Hits: 68.63%
# Epoch: 303, Loss: 0.0824, Val Hits: 64.24%, Test Hits: 69.51%
# Epoch: 304, Loss: 0.0823, Val Hits: 63.15%, Test Hits: 71.31%
# Epoch: 305, Loss: 0.0824, Val Hits: 63.12%, Test Hits: 67.25%
# Epoch: 306, Loss: 0.0826, Val Hits: 64.44%, Test Hits: 75.10%
# Epoch: 307, Loss: 0.0826, Val Hits: 61.50%, Test Hits: 74.01%
# Epoch: 308, Loss: 0.0820, Val Hits: 63.95%, Test Hits: 74.55%
# Epoch: 309, Loss: 0.0820, Val Hits: 61.52%, Test Hits: 73.99%
# Epoch: 310, Loss: 0.0824, Val Hits: 63.33%, Test Hits: 68.34%
# Epoch: 311, Loss: 0.0822, Val Hits: 63.29%, Test Hits: 74.98%
# Epoch: 312, Loss: 0.0823, Val Hits: 63.34%, Test Hits: 73.32%
# Epoch: 313, Loss: 0.0825, Val Hits: 63.08%, Test Hits: 72.11%
# Epoch: 314, Loss: 0.0829, Val Hits: 63.01%, Test Hits: 72.01%
# Epoch: 315, Loss: 0.0821, Val Hits: 63.55%, Test Hits: 67.11%
# Epoch: 316, Loss: 0.0821, Val Hits: 63.32%, Test Hits: 71.57%
# Epoch: 317, Loss: 0.0819, Val Hits: 62.16%, Test Hits: 72.91%
# Epoch: 318, Loss: 0.0831, Val Hits: 63.29%, Test Hits: 75.01%
# Epoch: 319, Loss: 0.0821, Val Hits: 65.35%, Test Hits: 76.45%
# Epoch: 320, Loss: 0.0818, Val Hits: 65.84%, Test Hits: 72.01%
# Epoch: 321, Loss: 0.0823, Val Hits: 65.84%, Test Hits: 74.23%
# Epoch: 322, Loss: 0.0820, Val Hits: 64.03%, Test Hits: 74.08%
# Epoch: 323, Loss: 0.0825, Val Hits: 65.00%, Test Hits: 73.55%
# Epoch: 324, Loss: 0.0824, Val Hits: 57.47%, Test Hits: 65.74%
# Epoch: 325, Loss: 0.0816, Val Hits: 50.58%, Test Hits: 56.52%
# Epoch: 326, Loss: 0.0822, Val Hits: 64.54%, Test Hits: 72.03%
# Epoch: 327, Loss: 0.0820, Val Hits: 64.82%, Test Hits: 73.15%
# Epoch: 328, Loss: 0.0820, Val Hits: 64.77%, Test Hits: 71.30%
# Epoch: 329, Loss: 0.0828, Val Hits: 65.70%, Test Hits: 72.48%
# Epoch: 330, Loss: 0.0819, Val Hits: 62.62%, Test Hits: 71.53%
# Epoch: 331, Loss: 0.0819, Val Hits: 65.58%, Test Hits: 73.08%
# Epoch: 332, Loss: 0.0822, Val Hits: 65.85%, Test Hits: 78.58%
# Epoch: 333, Loss: 0.0821, Val Hits: 50.67%, Test Hits: 50.44%
# Epoch: 334, Loss: 0.0818, Val Hits: 64.51%, Test Hits: 73.34%
# Epoch: 335, Loss: 0.0820, Val Hits: 64.84%, Test Hits: 77.64%
# Epoch: 336, Loss: 0.0813, Val Hits: 64.17%, Test Hits: 71.08%
# Epoch: 337, Loss: 0.0822, Val Hits: 65.98%, Test Hits: 71.22%
# Epoch: 338, Loss: 0.0821, Val Hits: 65.30%, Test Hits: 74.77%
# Epoch: 339, Loss: 0.0823, Val Hits: 53.46%, Test Hits: 73.45%
# Epoch: 340, Loss: 0.0815, Val Hits: 62.33%, Test Hits: 74.10%
# Epoch: 341, Loss: 0.0815, Val Hits: 65.06%, Test Hits: 77.26%
# Epoch: 342, Loss: 0.0819, Val Hits: 65.62%, Test Hits: 75.39%
# Epoch: 343, Loss: 0.0816, Val Hits: 64.58%, Test Hits: 75.16%
# Epoch: 344, Loss: 0.0826, Val Hits: 65.10%, Test Hits: 71.25%
# Epoch: 345, Loss: 0.0818, Val Hits: 63.69%, Test Hits: 73.53%
# Epoch: 346, Loss: 0.0818, Val Hits: 64.83%, Test Hits: 71.81%
# Epoch: 347, Loss: 0.0819, Val Hits: 62.19%, Test Hits: 67.06%
# Epoch: 348, Loss: 0.0820, Val Hits: 65.70%, Test Hits: 72.90%
# Epoch: 349, Loss: 0.0819, Val Hits: 61.31%, Test Hits: 69.33%
# Epoch: 350, Loss: 0.0815, Val Hits: 65.06%, Test Hits: 74.82%
# Epoch: 351, Loss: 0.0818, Val Hits: 63.47%, Test Hits: 69.91%
# Epoch: 352, Loss: 0.0816, Val Hits: 63.60%, Test Hits: 77.71%
# Epoch: 353, Loss: 0.0818, Val Hits: 62.65%, Test Hits: 69.07%
# Epoch: 354, Loss: 0.0820, Val Hits: 63.84%, Test Hits: 70.43%
# Epoch: 355, Loss: 0.0818, Val Hits: 64.32%, Test Hits: 69.33%
# Epoch: 356, Loss: 0.0817, Val Hits: 66.64%, Test Hits: 75.75%
# Epoch: 357, Loss: 0.0817, Val Hits: 63.90%, Test Hits: 74.41%
# Epoch: 358, Loss: 0.0813, Val Hits: 65.43%, Test Hits: 71.00%
# Epoch: 359, Loss: 0.0815, Val Hits: 63.48%, Test Hits: 73.22%
# Epoch: 360, Loss: 0.0816, Val Hits: 64.49%, Test Hits: 73.37%
# Epoch: 361, Loss: 0.0808, Val Hits: 62.54%, Test Hits: 72.93%
# Epoch: 362, Loss: 0.0811, Val Hits: 65.25%, Test Hits: 74.23%
# Epoch: 363, Loss: 0.0811, Val Hits: 63.20%, Test Hits: 72.85%
# Epoch: 364, Loss: 0.0814, Val Hits: 64.31%, Test Hits: 74.11%
# Epoch: 365, Loss: 0.0814, Val Hits: 65.48%, Test Hits: 74.26%
# Epoch: 366, Loss: 0.0816, Val Hits: 66.20%, Test Hits: 76.34%
# Epoch: 367, Loss: 0.0814, Val Hits: 65.37%, Test Hits: 75.81%
# Epoch: 368, Loss: 0.0820, Val Hits: 64.96%, Test Hits: 72.38%
# Epoch: 369, Loss: 0.0817, Val Hits: 63.43%, Test Hits: 76.40%
# Epoch: 370, Loss: 0.0820, Val Hits: 64.34%, Test Hits: 75.81%
# Epoch: 371, Loss: 0.0816, Val Hits: 65.31%, Test Hits: 71.51%
# Epoch: 372, Loss: 0.0810, Val Hits: 63.83%, Test Hits: 76.16%
# Epoch: 373, Loss: 0.0807, Val Hits: 65.21%, Test Hits: 75.99%
# Epoch: 374, Loss: 0.0813, Val Hits: 65.12%, Test Hits: 76.29%
# Epoch: 375, Loss: 0.0813, Val Hits: 66.01%, Test Hits: 75.88%
# Epoch: 376, Loss: 0.0817, Val Hits: 66.27%, Test Hits: 74.81%
# Epoch: 377, Loss: 0.0817, Val Hits: 65.12%, Test Hits: 75.30%
# Epoch: 378, Loss: 0.0812, Val Hits: 65.65%, Test Hits: 79.09%
# Epoch: 379, Loss: 0.0818, Val Hits: 65.36%, Test Hits: 79.24%
# Epoch: 380, Loss: 0.0819, Val Hits: 63.63%, Test Hits: 75.25%
# Epoch: 381, Loss: 0.0815, Val Hits: 65.04%, Test Hits: 75.88%
# Epoch: 382, Loss: 0.0818, Val Hits: 64.75%, Test Hits: 78.02%
# Epoch: 383, Loss: 0.0813, Val Hits: 63.04%, Test Hits: 75.75%
# Epoch: 384, Loss: 0.0816, Val Hits: 64.48%, Test Hits: 78.97%
# Epoch: 385, Loss: 0.0811, Val Hits: 63.09%, Test Hits: 78.13%
# Epoch: 386, Loss: 0.0811, Val Hits: 63.57%, Test Hits: 74.55%
# Epoch: 387, Loss: 0.0816, Val Hits: 64.54%, Test Hits: 73.45%
# Epoch: 388, Loss: 0.0809, Val Hits: 65.14%, Test Hits: 75.38%
# Epoch: 389, Loss: 0.0815, Val Hits: 65.82%, Test Hits: 72.02%
# Epoch: 390, Loss: 0.0813, Val Hits: 48.97%, Test Hits: 48.67%
# Epoch: 391, Loss: 0.0815, Val Hits: 65.62%, Test Hits: 75.16%
# Epoch: 392, Loss: 0.0814, Val Hits: 63.65%, Test Hits: 69.90%
# Epoch: 393, Loss: 0.0819, Val Hits: 61.81%, Test Hits: 73.01%
# Epoch: 394, Loss: 0.0813, Val Hits: 63.22%, Test Hits: 71.01%
# Epoch: 395, Loss: 0.0812, Val Hits: 65.56%, Test Hits: 75.76%
# Epoch: 396, Loss: 0.0811, Val Hits: 62.08%, Test Hits: 74.22%
# Epoch: 397, Loss: 0.0811, Val Hits: 63.69%, Test Hits: 74.75%
# Epoch: 398, Loss: 0.0814, Val Hits: 64.02%, Test Hits: 77.42%
# Epoch: 399, Loss: 0.0814, Val Hits: 62.73%, Test Hits: 62.60%
# Epoch: 400, Loss: 0.0812, Val Hits: 61.76%, Test Hits: 76.59%
# Final model:
# Epoch: 356, Val Hits: 66.64%, Test Hits: 75.75%
# Run 10 done.
# Mean Val Hits: 0.6713, SD Val Hits: 0.0071
# Mean Test Hits: 0.7672, SD Test Hits: 0.0265
